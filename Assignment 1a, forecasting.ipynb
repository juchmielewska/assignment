# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time          comp         round  day venue result   gf   ga  \
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0      RB Leipzig  ...  Match Report    NaN  12.0   8.0   NaN  NaN  0     0
# 1  Eint Frankfurt  ...  Match Report    NaN  23.0  10.0  16.6  1.0  0     0
# 2       Wolfsburg  ...  Match Report    NaN  24.0   8.0  18.4  0.0  0     0
# 3          Bochum  ...  Match Report    NaN  21.0  11.0  18.3  1.0  1     1
# 4      M'Gladbach  ...  Match Report    NaN  33.0  20.0  17.4  1.0  0     0
#
#   season           team
# 0   2023  Bayern Munich
# 1   2023  Bayern Munich
# 2   2023  Bayern Munich
# 3   2023  Bayern Munich
# 4   2023  Bayern Munich
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (2664, 27)

# %%
# 2 seasons * 32 squads * 38 matches
2 * 20 * 38
# Out:
# 1520

# %%
matches["team"].value_counts()
# Out:
# Liverpool              105
# Manchester City        102
# Chelsea                100
# Real Madrid             99
# Barcelona               95
# Sevilla                 95
# Internazionale          93
# Juventus                93
# Paris Saint Germain     91
# RB Leipzig              91
# Atletico Madrid         89
# Benfica                 87
# Milan                   87
# Club Brugge             86
# Bayern Munich           86
# Dortmund                84
# Porto                   79
# Sporting CP             78
# Ajax                    77
# Red Bull Salzburg       73
# Shakhtar Donetsk        56
# Villarreal              54
# Atalanta                52
# Lille                   49
# Manchester United       49
# Young Boys              48
# Besiktas                44
# Tottenham Hotspur       41
# Wolfsburg               41
# Rangers                 40
# Dinamo Zagreb           39
# Eintracht Frankfurt     39
# Marseille               39
# Zenit                   38
# Napoli                  38
# Viktoria Plzen          37
# Bayer Leverkusen        37
# Celtic                  36
# FC Copenhagen           31
# Dynamo Kyiv             24
# Sheriff Tiraspol        16
# Malmo                   14
# Maccabi Haifa           12
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result gf ga  \
# 0   2021-08-14  17:30  Premier League   Matchweek 1  Sat  Away      W  3  0
# 1   2021-08-21  12:30  Premier League   Matchweek 2  Sat  Home      W  2  0
# 2   2021-08-28  17:30  Premier League   Matchweek 3  Sat  Home      D  1  1
# 3   2021-09-12  16:30  Premier League   Matchweek 4  Sun  Away      W  3  0
# 4   2021-09-15  20:00    Champions Lg   Group stage  Wed  Home      W  3  2
# ..         ...    ...             ...           ...  ...   ...    ... .. ..
# 37  2023-03-05  16:30  Premier League  Matchweek 26  Sun  Home      W  7  0
# 38  2023-03-11  12:30  Premier League  Matchweek 27  Sat  Away      L  0  1
# 39  2023-03-15  21:00    Champions Lg   Round of 16  Wed  Away      L  0  1
# 40  2023-04-01  12:30  Premier League  Matchweek 29  Sat  Away      L  1  4
# 41  2023-04-04  20:00  Premier League   Matchweek 8  Tue  Away      D  0  0
#
#            opponent  ...  match report                        notes    sh  \
# 0      Norwich City  ...  Match Report                          NaN  19.0
# 1           Burnley  ...  Match Report                          NaN  27.0
# 2           Chelsea  ...  Match Report                          NaN  23.0
# 3      Leeds United  ...  Match Report                          NaN  30.0
# 4          it Milan  ...  Match Report                          NaN  22.0
# ..              ...  ...           ...                          ...   ...
# 37   Manchester Utd  ...  Match Report                          NaN  18.0
# 38      Bournemouth  ...  Match Report                          NaN  14.0
# 39   es Real Madrid  ...  Match Report  Leg 2 of 2; Real Madrid won   9.0
# 40  Manchester City  ...  Match Report                          NaN   4.0
# 41          Chelsea  ...  Match Report                          NaN   7.0
#
#     sot  dist   fk pk pkatt season       team
# 0   6.0  17.3  1.0  0     0   2022  Liverpool
# 1   8.0  16.1  0.0  0     0   2022  Liverpool
# 2   6.0  16.2  0.0  1     1   2022  Liverpool
# 3   8.0  16.1  1.0  0     0   2022  Liverpool
# 4   7.0  19.1  0.0  0     1   2022  Liverpool
# ..  ...   ...  ... ..   ...    ...        ...
# 37  8.0  12.7  0.0  0     0   2023  Liverpool
# 38  5.0  18.5  0.0  0     1   2023  Liverpool
# 39  5.0  17.8  0.0  0     0   2023  Liverpool
# 40  1.0  15.9  0.0  0     0   2023  Liverpool
# 41  3.0  25.4  0.0  0     0   2023  Liverpool
#
# [105 rows x 27 columns]

# %%
matches["round"].value_counts()
# Out:
# Group stage               384
# Regular season            228
# Round of 16               107
# Matchweek 13               52
# Matchweek 11               52
#                          ...
# First qualifying round      4
# DFL-Supercup                4
# Trophée des Champions       3
# FA Community Shield         3
# Relegation round            1
# Name: round, Length: 66, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf               object
# ga               object
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                      object
# ga                      object
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                   object
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# venue_code                int8
# opp_code                 int16
# hour                     int64
# day_code                 int32
# target                   int64
# dtype: object

# %%
matches["gf"] = pd.to_numeric(matches["gf"],errors = 'coerce')
matches["ga"] = pd.to_numeric(matches["gf"],errors = 'coerce')
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                   object
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# venue_code                int8
# opp_code                 int16
# hour                     int64
# day_code                 int32
# target                   int64
# dtype: object

# %%
# converting from a string into categories --> and categories into numbers 
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches

# venue code:
# 0 --> Away
# 1 --> Home
# Out:
#          date   time          comp         round  day venue result   gf   ga  \
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..        ...    ...           ...           ...  ...   ...    ...  ...  ...
# 39 2022-04-25  20:30     Süper Lig  Matchweek 34  Mon  Home      L    0    3
# 40 2022-05-01  16:00     Süper Lig  Matchweek 35  Sun  Away      W    3    2
# 41 2022-05-08  19:00     Süper Lig  Matchweek 36  Sun  Home      D    1    1
# 42 2022-05-15  16:00     Süper Lig  Matchweek 37  Sun  Away      W    2    0
# 43 2022-05-21  19:00     Süper Lig  Matchweek 38  Sat  Home      D    1    1
#
#           opponent  ...  notes    sh   sot  dist   fk pk pkatt season  \
# 0       RB Leipzig  ...    NaN  12.0   8.0   NaN  NaN  0     0   2023
# 1   Eint Frankfurt  ...    NaN  23.0  10.0  16.6  1.0  0     0   2023
# 2        Wolfsburg  ...    NaN  24.0   8.0  18.4  0.0  0     0   2023
# 3           Bochum  ...    NaN  21.0  11.0  18.3  1.0  1     1   2023
# 4       M'Gladbach  ...    NaN  33.0  20.0  17.4  1.0  0     0   2023
# ..             ...  ...    ...   ...   ...   ...  ... ..   ...    ...
# 39       Kasımpaşa  ...    NaN  15.0   3.0   NaN  NaN  0     0   2022
# 40     Kayserispor  ...    NaN  17.0   6.0   NaN  NaN  1     1   2022
# 41      Fenerbahçe  ...    NaN   9.0   3.0   NaN  NaN  1     2   2022
# 42         Göztepe  ...    NaN   8.0   3.0   NaN  NaN  0     0   2022
# 43       Konyaspor  ...    NaN  21.0   5.0   NaN  NaN  0     0   2022
#
#              team  venue_code
# 0   Bayern Munich           0
# 1   Bayern Munich           0
# 2   Bayern Munich           1
# 3   Bayern Munich           0
# 4   Bayern Munich           1
# ..            ...         ...
# 39       Besiktas           1
# 40       Besiktas           0
# 41       Besiktas           1
# 42       Besiktas           0
# 43       Besiktas           1
#
# [2664 rows x 28 columns]

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches
# Out:
#          date   time          comp         round  day venue result   gf   ga  \
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..        ...    ...           ...           ...  ...   ...    ...  ...  ...
# 39 2022-04-25  20:30     Süper Lig  Matchweek 34  Mon  Home      L    0    3
# 40 2022-05-01  16:00     Süper Lig  Matchweek 35  Sun  Away      W    3    2
# 41 2022-05-08  19:00     Süper Lig  Matchweek 36  Sun  Home      D    1    1
# 42 2022-05-15  16:00     Süper Lig  Matchweek 37  Sun  Away      W    2    0
# 43 2022-05-21  19:00     Süper Lig  Matchweek 38  Sat  Home      D    1    1
#
#           opponent  ...    sh   sot  dist   fk pk pkatt season           team  \
# 0       RB Leipzig  ...  12.0   8.0   NaN  NaN  0     0   2023  Bayern Munich
# 1   Eint Frankfurt  ...  23.0  10.0  16.6  1.0  0     0   2023  Bayern Munich
# 2        Wolfsburg  ...  24.0   8.0  18.4  0.0  0     0   2023  Bayern Munich
# 3           Bochum  ...  21.0  11.0  18.3  1.0  1     1   2023  Bayern Munich
# 4       M'Gladbach  ...  33.0  20.0  17.4  1.0  0     0   2023  Bayern Munich
# ..             ...  ...   ...   ...   ...  ... ..   ...    ...            ...
# 39       Kasımpaşa  ...  15.0   3.0   NaN  NaN  0     0   2022       Besiktas
# 40     Kayserispor  ...  17.0   6.0   NaN  NaN  1     1   2022       Besiktas
# 41      Fenerbahçe  ...   9.0   3.0   NaN  NaN  1     2   2022       Besiktas
# 42         Göztepe  ...   8.0   3.0   NaN  NaN  0     0   2022       Besiktas
# 43       Konyaspor  ...  21.0   5.0   NaN  NaN  0     0   2022       Besiktas
#
#    venue_code  opp_code
# 0           0       230
# 1           0        85
# 2           1       333
# 3           0        44
# 4           1       183
# ..        ...       ...
# 39          1       154
# 40          0       155
# 41          1       109
# 42          0       130
# 43          1       157
#
# [2664 rows x 29 columns]

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches
# Out:
#          date   time          comp         round  day venue result   gf   ga  \
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..        ...    ...           ...           ...  ...   ...    ...  ...  ...
# 39 2022-04-25  20:30     Süper Lig  Matchweek 34  Mon  Home      L    0    3
# 40 2022-05-01  16:00     Süper Lig  Matchweek 35  Sun  Away      W    3    2
# 41 2022-05-08  19:00     Süper Lig  Matchweek 36  Sun  Home      D    1    1
# 42 2022-05-15  16:00     Süper Lig  Matchweek 37  Sun  Away      W    2    0
# 43 2022-05-21  19:00     Süper Lig  Matchweek 38  Sat  Home      D    1    1
#
#           opponent  ...   sot  dist   fk  pk pkatt season           team  \
# 0       RB Leipzig  ...   8.0   NaN  NaN   0     0   2023  Bayern Munich
# 1   Eint Frankfurt  ...  10.0  16.6  1.0   0     0   2023  Bayern Munich
# 2        Wolfsburg  ...   8.0  18.4  0.0   0     0   2023  Bayern Munich
# 3           Bochum  ...  11.0  18.3  1.0   1     1   2023  Bayern Munich
# 4       M'Gladbach  ...  20.0  17.4  1.0   0     0   2023  Bayern Munich
# ..             ...  ...   ...   ...  ...  ..   ...    ...            ...
# 39       Kasımpaşa  ...   3.0   NaN  NaN   0     0   2022       Besiktas
# 40     Kayserispor  ...   6.0   NaN  NaN   1     1   2022       Besiktas
# 41      Fenerbahçe  ...   3.0   NaN  NaN   1     2   2022       Besiktas
# 42         Göztepe  ...   3.0   NaN  NaN   0     0   2022       Besiktas
# 43       Konyaspor  ...   5.0   NaN  NaN   0     0   2022       Besiktas
#
#    venue_code opp_code  hour
# 0           0      230    20
# 1           0       85    20
# 2           1      333    17
# 3           0       44    17
# 4           1      183    18
# ..        ...      ...   ...
# 39          1      154    20
# 40          0      155    16
# 41          1      109    19
# 42          0      130    16
# 43          1      157    19
#
# [2664 rows x 30 columns]

# %%
matches["day_code"] = matches["date"].dt.dayofweek
matches

# Monday - 0
# Thuesday - 1
# ...
# Out:
#          date   time          comp         round  day venue result   gf   ga  \
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..        ...    ...           ...           ...  ...   ...    ...  ...  ...
# 39 2022-04-25  20:30     Süper Lig  Matchweek 34  Mon  Home      L    0    3
# 40 2022-05-01  16:00     Süper Lig  Matchweek 35  Sun  Away      W    3    2
# 41 2022-05-08  19:00     Süper Lig  Matchweek 36  Sun  Home      D    1    1
# 42 2022-05-15  16:00     Süper Lig  Matchweek 37  Sun  Away      W    2    0
# 43 2022-05-21  19:00     Süper Lig  Matchweek 38  Sat  Home      D    1    1
#
#           opponent  ...  dist   fk  pk  pkatt season           team  \
# 0       RB Leipzig  ...   NaN  NaN   0      0   2023  Bayern Munich
# 1   Eint Frankfurt  ...  16.6  1.0   0      0   2023  Bayern Munich
# 2        Wolfsburg  ...  18.4  0.0   0      0   2023  Bayern Munich
# 3           Bochum  ...  18.3  1.0   1      1   2023  Bayern Munich
# 4       M'Gladbach  ...  17.4  1.0   0      0   2023  Bayern Munich
# ..             ...  ...   ...  ...  ..    ...    ...            ...
# 39       Kasımpaşa  ...   NaN  NaN   0      0   2022       Besiktas
# 40     Kayserispor  ...   NaN  NaN   1      1   2022       Besiktas
# 41      Fenerbahçe  ...   NaN  NaN   1      2   2022       Besiktas
# 42         Göztepe  ...   NaN  NaN   0      0   2022       Besiktas
# 43       Konyaspor  ...   NaN  NaN   0      0   2022       Besiktas
#
#    venue_code opp_code hour  day_code
# 0           0      230   20         5
# 1           0       85   20         4
# 2           1      333   17         6
# 3           0       44   17         6
# 4           1      183   18         5
# ..        ...      ...  ...       ...
# 39          1      154   20         0
# 40          0      155   16         6
# 41          1      109   19         6
# 42          0      130   16         6
# 43          1      157   19         5
#
# [2664 rows x 31 columns]

# %%
matches["target"] = (matches["result"] == "W").astype("int")
matches

# zbiorobo; można rozdzielić
# Lost [L] --> 0 
# Draw [D] --> 0
# Win [W] --> 1
# Out:
#          date   time          comp         round  day venue result   gf   ga  \
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..        ...    ...           ...           ...  ...   ...    ...  ...  ...
# 39 2022-04-25  20:30     Süper Lig  Matchweek 34  Mon  Home      L    0    3
# 40 2022-05-01  16:00     Süper Lig  Matchweek 35  Sun  Away      W    3    2
# 41 2022-05-08  19:00     Süper Lig  Matchweek 36  Sun  Home      D    1    1
# 42 2022-05-15  16:00     Süper Lig  Matchweek 37  Sun  Away      W    2    0
# 43 2022-05-21  19:00     Süper Lig  Matchweek 38  Sat  Home      D    1    1
#
#           opponent  ...   fk  pk  pkatt  season           team venue_code  \
# 0       RB Leipzig  ...  NaN   0      0    2023  Bayern Munich          0
# 1   Eint Frankfurt  ...  1.0   0      0    2023  Bayern Munich          0
# 2        Wolfsburg  ...  0.0   0      0    2023  Bayern Munich          1
# 3           Bochum  ...  1.0   1      1    2023  Bayern Munich          0
# 4       M'Gladbach  ...  1.0   0      0    2023  Bayern Munich          1
# ..             ...  ...  ...  ..    ...     ...            ...        ...
# 39       Kasımpaşa  ...  NaN   0      0    2022       Besiktas          1
# 40     Kayserispor  ...  NaN   1      1    2022       Besiktas          0
# 41      Fenerbahçe  ...  NaN   1      2    2022       Besiktas          1
# 42         Göztepe  ...  NaN   0      0    2022       Besiktas          0
# 43       Konyaspor  ...  NaN   0      0    2022       Besiktas          1
#
#    opp_code hour day_code  target
# 0       230   20        5       1
# 1        85   20        4       1
# 2       333   17        6       1
# 3        44   17        6       1
# 4       183   18        5       0
# ..      ...  ...      ...     ...
# 39      154   20        0       0
# 40      155   16        6       1
# 41      109   19        6       0
# 42      130   16        6       1
# 43      157   19        5       0
#
# [2664 rows x 32 columns]

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\jchmi\anaconda3\lib\site-packages (1.0.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.2-cp39-cp39-win_amd64.whl (8.4 MB)
#      ---------------------------------------- 8.4/8.4 MB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jchmi\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\jchmi\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\jchmi\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      -------------------------------------- 298.0/298.0 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: joblib, scikit-learn
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Successfully installed joblib-1.2.0 scikit-learn-1.2.2

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.2.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: c:\users\jchmi\anaconda3\lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: scikit-learn-intelex

# %%
from sklearn.ensemble import RandomForestClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 from sklearn.ensemble import RandomForestClassifier
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/__init__.py:5
#       1 """
#       2 The :mod:`sklearn.ensemble` module includes ensemble-based methods for
#       3 classification, regression and anomaly detection.
#       4 """
# ----> 5 from ._base import BaseEnsemble
#       6 from ._forest import RandomForestClassifier
#       7 from ._forest import RandomForestRegressor
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_base.py:18
#      16 from ..base import BaseEstimator
#      17 from ..base import MetaEstimatorMixin
# ---> 18 from ..tree import (
#      19     DecisionTreeRegressor,
#      20     BaseDecisionTree,
#      21     DecisionTreeClassifier,
#      22 )
#      23 from ..utils import Bunch, _print_elapsed_time, deprecated
#      24 from ..utils import check_random_state
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/tree/__init__.py:6
#       1 """
#       2 The :mod:`sklearn.tree` module includes decision tree-based models for
#       3 classification and regression.
#       4 """
# ----> 6 from ._classes import BaseDecisionTree
#       7 from ._classes import DecisionTreeClassifier
#       8 from ._classes import DecisionTreeRegressor
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/tree/_classes.py:42
#      39 from ..utils.validation import check_is_fitted
#      40 from ..utils._param_validation import Hidden, Interval, StrOptions
# ---> 42 from ._criterion import Criterion
#      43 from ._splitter import Splitter
#      44 from ._tree import DepthFirstTreeBuilder
#
# File sklearn/tree/_criterion.pyx:1, in init sklearn.tree._criterion()
#
# File sklearn/tree/_splitter.pyx:1, in init sklearn.tree._splitter()
#
# File sklearn/tree/_tree.pyx:1, in init sklearn.tree._tree()
#
# ModuleNotFoundError: No module named 'sklearn.neighbors'

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
train = matches[matches["date"] < '2023-01-01']

# %%
test = matches[matches["date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 rf.fit(train[predictors], train["target"])
#
# NameError: name 'rf' is not defined

# %%
preds = rf.predict(test[predictors])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 preds = rf.predict(test[predictors])
#
# NameError: name 'rf' is not defined

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)
acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 acc = accuracy_score(test["target"], preds)
#       2 acc
#
# NameError: name 'preds' is not defined

# %%
#error = accuracy_score(test["target"], preds
#error

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0    1
# actual
# 0          68  131
# 1          61  213

# %%
from sklearn.metrics import precision_score
precision_score(test["target"], preds)
# Out:
# 0.6191860465116279

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
# C:\Users\jchmi\AppData\Local\Temp\ipykernel_2616\1516339790.py:3: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['ga', 'gf'], dtype='object')
#   rolling_stats = group[cols].rolling(3, closed='left').mean()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2616\3000427820.py in <module>
# ----> 1 rolling_averages(group, cols, new_cols)
#
# ~\AppData\Local\Temp\ipykernel_2616\1516339790.py in rolling_averages(group, cols, new_cols)
#       2     group = group.sort_values("date")
#       3     rolling_stats = group[cols].rolling(3, closed='left').mean()
# ----> 4     group[new_cols] = rolling_stats
#       5     group = group.dropna(subset=new_cols)
#       6     return group
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3641             self._setitem_frame(key, value)
#    3642         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3643             self._setitem_array(key, value)
#    3644         elif isinstance(value, DataFrame):
#    3645             self._set_item_frame_value(key, value)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3683
#    3684             if isinstance(value, DataFrame):
# -> 3685                 check_key_length(self.columns, key, value)
#    3686                 for k1, k2 in zip(key, value.columns):
#    3687                     self[k1] = value[k2]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexers\utils.py in check_key_length(columns, key, value)
#     426     if columns.is_unique:
#     427         if len(value.columns) != len(key):
# --> 428             raise ValueError("Columns must be same length as key")
#     429     else:
#     430         # Missing keys in columns are represented as -1
#
# ValueError: Columns must be same length as key

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)
precision

# %%
combined

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined

# %%
combined.head(10)
