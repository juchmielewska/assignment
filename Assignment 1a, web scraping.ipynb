# %%
# defining the website that will be the source of the data
standings_url = "https://fbref.com/en/comps/8/Champions-League-Stats#all_rank_key"

# %%
# downloading html of the website
import requests
data = requests.get(standings_url)

# %%
# selecting the League Table code
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standings_table = all.select('table.stats_table')[8]

# %%
# finding all 'a' tags and links inside of League Table
links = league_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if 'squads' in l]

# %%
# completing the links and selecting 8 teams
team_urls = [f"https://fbref.com{l}" for l in links]
team_urls = team_urls[:8]
team_urls
# Out:
# ['https://fbref.com/en/squads/054efa67/Bayern-Munich-Stats',
#  'https://fbref.com/en/squads/d48ad4ff/Napoli-Stats',
#  'https://fbref.com/en/squads/a77c513e/Benfica-Stats',
#  'https://fbref.com/en/squads/53a2f082/Real-Madrid-Stats',
#  'https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/dc56fe14/Milan-Stats',
#  'https://fbref.com/en/squads/d609edc0/Internazionale-Stats']

# %%
data = requests.get(team_urls[0])

# %%
import pandas as pd
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]
links
# Out:
# ['/en/squads/054efa67/2022-2023/matchlogs/all_comps/shooting/Bayern-Munich-Match-Logs-All-Competitions',
#  '/en/squads/054efa67/2022-2023/matchlogs/all_comps/shooting/Bayern-Munich-Match-Logs-All-Competitions',
#  '/en/squads/054efa67/2022-2023/matchlogs/all_comps/shooting/Bayern-Munich-Match-Logs-All-Competitions',
#  '/en/squads/054efa67/2022-2023/matchlogs/all_comps/shooting/Bayern-Munich-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")
shooting = pd.read_html(data.text, match="Shooting")[0]
shooting.head()
# Out:
#   For Bayern Munich                                                          \
#                Date   Time          Comp         Round  Day Venue Result GF
# 0        2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5
# 1        2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6
# 2        2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2
# 3        2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7
# 4        2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1
#
#                       ... Standard               Expected                    \
#   GA        Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh G-xG
# 0  3      RB Leipzig  ...      NaN  NaN  0     0      NaN  NaN     NaN  NaN
# 1  1  Eint Frankfurt  ...     16.6  1.0  0     0      4.0  4.0    0.18  2.0
# 2  0       Wolfsburg  ...     18.4  0.0  0     0      2.0  2.0    0.09  0.0
# 3  0          Bochum  ...     18.3  1.0  1     1      2.9  2.2    0.11  3.1
# 4  1      M'Gladbach  ...     17.4  1.0  0     0      2.8  2.8    0.09 -1.8
#
#           Unnamed: 25_level_0
#   np:G-xG        Match Report
# 0     NaN        Match Report
# 1     2.0        Match Report
# 2     0.0        Match Report
# 3     2.8        Match Report
# 4    -1.8        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
team_data
# Out:
#           Date   Time          Comp           Round  Day Venue Result   GF  \
# 0   2022-07-30  20:30  DFL-Supercup    DFL-Supercup  Sat  Away      W  5.0
# 1   2022-08-05  20:30    Bundesliga     Matchweek 1  Fri  Away      W  6.0
# 2   2022-08-14  17:30    Bundesliga     Matchweek 2  Sun  Home      W  2.0
# 3   2022-08-21  17:30    Bundesliga     Matchweek 3  Sun  Away      W  7.0
# 4   2022-08-27  18:30    Bundesliga     Matchweek 4  Sat  Home      D  1.0
# 5   2022-08-31  20:46     DFB-Pokal     Round of 64  Wed  Away      W  5.0
# 6   2022-09-03  15:30    Bundesliga     Matchweek 5  Sat  Away      D  1.0
# 7   2022-09-07  21:00  Champions Lg     Group stage  Wed  Away      W  2.0
# 8   2022-09-10  15:30    Bundesliga     Matchweek 6  Sat  Home      D  2.0
# 9   2022-09-13  21:00  Champions Lg     Group stage  Tue  Home      W  2.0
# 10  2022-09-17  15:30    Bundesliga     Matchweek 7  Sat  Away      L  0.0
# 10  1.0           Augsburg  ...    4-2-3-1          Marco Fritz  Match Report
# 11  0.0         Leverkusen  ...    4-2-3-1       Tobias Stieler  Match Report
# 12  0.0  cz Viktoria Plzeň  ...    4-2-3-1     Nikola Dabanović  Match Report
# 13  2.0           Dortmund  ...    4-2-3-1        Deniz Aytekin  Match Report
# 14  2.0  cz Viktoria Plzeň  ...    4-2-3-1   Bartosz Frankowski  Match Report
# 15  0.0           Freiburg  ...    4-2-3-1     Sascha Stegemann  Match Report
# 16  2.0           Augsburg  ...    4-2-3-1      Bastian Dankert  Match Report
# 17  0.0         Hoffenheim  ...    4-2-3-1       Sven Jablonski  Match Report
# 18  0.0       es Barcelona  ...    4-2-3-1       Anthony Taylor  Match Report
# 19  2.0           Mainz 05  ...    4-2-3-1         Felix Zwayer  Match Report
# 20  0.0           it Inter  ...    4-2-3-1        Ivan Kružliak  Match Report
# 21  2.0         Hertha BSC  ...    4-2-3-1      Bastian Dankert  Match Report
# 22  1.0      Werder Bremen  ...    4-2-3-1      Robert Hartmann  Match Report
# 23  0.0         Schalke 04  ...    4-2-3-1         Felix Zwayer  Match Report
# 24  1.0         RB Leipzig  ...    4-2-3-1       Daniel Siebert  Match Report
# 25  1.0               Köln  ...    4-2-3-1       Tobias Stieler  Match Report
# 26  1.0     Eint Frankfurt  ...    4-1-4-1       Sven Jablonski  Match Report
# 27  0.0           Mainz 05  ...    3-1-4-2        Deniz Aytekin  Match Report
# 28  2.0          Wolfsburg  ...    4-2-3-1          Harm Osmers  Match Report
# 29  0.0             Bochum  ...    3-1-4-2  Matthias Jöllenbeck  Match Report
# 30  0.0       fr Paris S-G  ...      3-4-3       Michael Oliver  Match Report
# 31  3.0         M'Gladbach  ...    3-1-4-2          Tobias Welz  Match Report
# 32  0.0       Union Berlin  ...    4-2-3-1          Marco Fritz  Match Report
# 33  1.0          Stuttgart  ...    4-2-3-1    Christian Dingert  Match Report
# 34  0.0       fr Paris S-G  ...    4-2-3-1       Daniele Orsato  Match Report
# 35  3.0           Augsburg  ...      3-4-3   Florian Badstübner  Match Report
# 36  2.0         Leverkusen  ...    3-1-4-2       Tobias Stieler  Match Report
# 37  2.0           Dortmund  ...    4-2-3-1          Marco Fritz  Match Report
# 38  2.0           Freiburg  ...    4-2-3-1          Harm Osmers  Match Report
#
#                             Notes  Sh SoT  Dist   FK PK  PKatt
# 0                             NaN  12   8   NaN  NaN  0      0
# 1                             NaN  23  10  16.6  1.0  0      0
# 2                             NaN  24   8  18.4  0.0  0      0
# 3                             NaN  21  11  18.3  1.0  1      1
# 4                             NaN  33  20  17.4  1.0  0      0
# 5                             NaN  28  18   NaN  NaN  0      0
# 6                             NaN  21   6  18.1  0.0  0      0
# 7                             NaN  21  11  18.7  1.0  0      0
# 8                             NaN  19   6  17.5  1.0  0      0
# 9                             NaN  13   4  17.7  0.0  0      0
# 10                            NaN  19   6  18.8  0.0  0      0
# 11                            NaN  20   9  16.6  2.0  0      0
# 12                            NaN  21  13  19.7  3.0  0      0
# 13                            NaN   9   3  20.5  0.0  0      0
# 14                            NaN  15   8  16.3  0.0  0      0
# 15                            NaN  16   8  18.4  0.0  0      0
# 16                            NaN  28  15   NaN  NaN  0      0
# 17                            NaN  21   9  13.9  0.0  0      0
# 18                            NaN  14   7  14.8  0.0  0      0
# 19                            NaN  23  12  15.3  0.0  0      1
# 20                            NaN  23   8  20.3  1.0  0      0
# 21                            NaN  14   4  17.1  1.0  0      0
# 22                            NaN  20   9  14.4  0.0  0      1
# 23                            NaN  21   6  18.7  0.0  0      0
# 24                            NaN   7   2  13.9  0.0  0      0
# 25                            NaN  25   7  17.3  0.0  0      0
# 26                            NaN  14   5  17.9  0.0  0      0
# 27                            NaN  21   9   NaN  NaN  0      0
# 28                            NaN   9   4  19.6  0.0  0      0
# 29                            NaN  22  11  16.7  0.0  1      1
# 30                     Leg 1 of 2  18   7  17.5  2.0  0      0
# 31                            NaN  13   5  18.4  0.0  0      0
# 32                            NaN  20   9  13.8  0.0  0      0
# 33                            NaN  14   6  14.9  0.0  0      0
# 34  Leg 2 of 2; Bayern Munich won  12   5  14.6  0.0  0      0
# 35                            NaN  23   8  16.1  1.0  0      0
# 36                            NaN  11   6  15.0  0.0  0      0
# 37                            NaN  16   9  16.5  0.0  0      0
# 38                            NaN  16   4   NaN  NaN  0      0
#
# [39 rows x 25 columns]

# %%
years = list(range(2023, 2021, -1))
years
# Out:
# [2023, 2022]

# %%
all_matches =[]

# %%
standings_url = "https://fbref.com/en/comps/8/Champions-League-Stats#all_rank_key"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[8]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    team_urls = team_urls[:8]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
      #  team_data = team_data[team_data["Comp"] == "Cahmpionms League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
len(all_matches)
# Out:
# 16

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time          comp         round  day venue result   gf   ga  \
# 0   2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1   2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2   2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3   2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4   2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..         ...    ...           ...           ...  ...   ...    ...  ...  ...
# 46  2022-04-30  21:00       La Liga  Matchweek 34  Sat  Away      L    0    2
# 47  2022-05-08  21:00       La Liga  Matchweek 35  Sun  Home      W    1    0
# 48  2022-05-11  21:30       La Liga  Matchweek 36  Wed  Away      W    2    0
# 49  2022-05-15  19:30       La Liga  Matchweek 37  Sun  Home      D    1    1
# 50  2022-05-22  22:00       La Liga  Matchweek 38  Sun  Away      W    2    1
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0       RB Leipzig  ...  Match Report    NaN  12.0   8.0   NaN  NaN  0     0
# 1   Eint Frankfurt  ...  Match Report    NaN  23.0  10.0  16.6  1.0  0     0
# 2        Wolfsburg  ...  Match Report    NaN  24.0   8.0  18.4  0.0  0     0
# 3           Bochum  ...  Match Report    NaN  21.0  11.0  18.3  1.0  1     1
# 4       M'Gladbach  ...  Match Report    NaN  33.0  20.0  17.4  1.0  0     0
# ..             ...  ...           ...    ...   ...   ...   ...  ... ..   ...
# 46   Athletic Club  ...  Match Report    NaN   9.0   3.0  19.7  1.0  0     0
# 47     Real Madrid  ...  Match Report    NaN  15.0   1.0  19.3  0.0  1     1
# 48           Elche  ...  Match Report    NaN  11.0   5.0  19.1  0.0  0     0
# 49         Sevilla  ...  Match Report    NaN  12.0   3.0  16.3  0.0  0     0
# 50   Real Sociedad  ...  Match Report    NaN   6.0   5.0  18.7  0.0  0     0
#
#    season             team
# 0    2023    Bayern Munich
# 1    2023    Bayern Munich
# 2    2023    Bayern Munich
# 3    2023    Bayern Munich
# 4    2023    Bayern Munich
# ..    ...              ...
# 46   2022  Atletico Madrid
# 47   2022  Atletico Madrid
# 48   2022  Atletico Madrid
# 49   2022  Atletico Madrid
# 50   2022  Atletico Madrid
#
# [760 rows x 27 columns]

# %%
match_df.to_csv("matches.csv")
