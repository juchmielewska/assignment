# %%
# defining the website that will be the source of the data
standings_url = "https://fbref.com/en/comps/8/Champions-League-Stats#all_rank_key"

# %%
# downloading html of the website
import requests
data = requests.get(standings_url)

# %%
# selecting the League Table code
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[8]

# %%
# finding all 'a' tags and links inside of League Table
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
# completing the links and selecting 8 teams
team_urls = [f"https://fbref.com{l}" for l in links]
#team_urls = team_urls[:8]
team_urls
# Out:
# ['https://fbref.com/en/squads/054efa67/Bayern-Munich-Stats',
#  'https://fbref.com/en/squads/d48ad4ff/Napoli-Stats',
#  'https://fbref.com/en/squads/a77c513e/Benfica-Stats',
#  'https://fbref.com/en/squads/53a2f082/Real-Madrid-Stats',
#  'https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/dc56fe14/Milan-Stats',
#  'https://fbref.com/en/squads/d609edc0/Internazionale-Stats',
#  'https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbref.com/en/squads/e2d8892c/Paris-Saint-Germain-Stats',
#  'https://fbref.com/en/squads/5e876ee6/Porto-Stats',
#  'https://fbref.com/en/squads/acbb6a5b/RB-Leipzig-Stats',
#  'https://fbref.com/en/squads/add600ae/Dortmund-Stats',
#  'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/f1e6c5f1/Club-Brugge-Stats',
#  'https://fbref.com/en/squads/f0ac8ee6/Eintracht-Frankfurt-Stats',
#  'https://fbref.com/en/squads/206d90db/Barcelona-Stats',
#  'https://fbref.com/en/squads/13dc44fd/Sporting-CP-Stats',
#  'https://fbref.com/en/squads/5725cc7b/Marseille-Stats',
#  'https://fbref.com/en/squads/e89d5a28/Shakhtar-Donetsk-Stats',
#  'https://fbref.com/en/squads/50f2a074/Red-Bull-Salzburg-Stats',
#  'https://fbref.com/en/squads/19c3f8c4/Ajax-Stats',
#  'https://fbref.com/en/squads/db3b9613/Atletico-Madrid-Stats',
#  'https://fbref.com/en/squads/c7a9f859/Bayer-Leverkusen-Stats',
#  'https://fbref.com/en/squads/ad2be733/Sevilla-Stats',
#  'https://fbref.com/en/squads/edd0d381/Dinamo-Zagreb-Stats',
#  'https://fbref.com/en/squads/e0652b02/Juventus-Stats',
#  'https://fbref.com/en/squads/18050b20/FC-Copenhagen-Stats',
#  'https://fbref.com/en/squads/187832f5/Maccabi-Haifa-Stats',
#  'https://fbref.com/en/squads/b81aa4fa/Celtic-Stats',
#  'https://fbref.com/en/squads/02cd81bf/Viktoria-Plzen-Stats',
#  'https://fbref.com/en/squads/86b7acd2/Rangers-Stats']

# %%
data = requests.get(team_urls[0])

# %%
import pandas as pd
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]
links
# Out:
# ['/en/squads/054efa67/2022-2023/matchlogs/all_comps/shooting/Bayern-Munich-Match-Logs-All-Competitions',
#  '/en/squads/054efa67/2022-2023/matchlogs/all_comps/shooting/Bayern-Munich-Match-Logs-All-Competitions',
#  '/en/squads/054efa67/2022-2023/matchlogs/all_comps/shooting/Bayern-Munich-Match-Logs-All-Competitions',
#  '/en/squads/054efa67/2022-2023/matchlogs/all_comps/shooting/Bayern-Munich-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")
shooting = pd.read_html(data.text, match="Shooting")[0]
shooting
# Out:
#    For Bayern Munich                                                          \
#                 Date   Time          Comp           Round  Day Venue  Result
# 0         2022-07-30  20:30  DFL-Supercup    DFL-Supercup  Sat  Away       W
# 1         2022-08-05  20:30    Bundesliga     Matchweek 1  Fri  Away       W
# 2         2022-08-14  17:30    Bundesliga     Matchweek 2  Sun  Home       W
# 3         2022-08-21  17:30    Bundesliga     Matchweek 3  Sun  Away       W
# 4         2022-08-27  18:30    Bundesliga     Matchweek 4  Sat  Home       D
# 5         2022-08-31  20:46     DFB-Pokal     Round of 64  Wed  Away       W
# 6         2022-09-03  15:30    Bundesliga     Matchweek 5  Sat  Away       D
# 7         2022-09-07  21:00  Champions Lg     Group stage  Wed  Away       W
# 8         2022-09-10  15:30    Bundesliga     Matchweek 6  Sat  Home       D
# 9         2022-09-13  21:00  Champions Lg     Group stage  Tue  Home       W
# 10        2022-09-17  15:30    Bundesliga     Matchweek 7  Sat  Away       L
# 11        2022-09-30  20:30    Bundesliga     Matchweek 8  Fri  Home       W
# 12        2022-10-04  18:45  Champions Lg     Group stage  Tue  Home       W
# 13        2022-10-08  18:30    Bundesliga     Matchweek 9  Sat  Away       D
# 14        2022-10-12  21:00  Champions Lg     Group stage  Wed  Away       W
# 15        2022-10-16  19:30    Bundesliga    Matchweek 10  Sun  Home       W
# 16        2022-10-19  20:45     DFB-Pokal     Round of 32  Wed  Away       W
# 17        2022-10-22  15:30    Bundesliga    Matchweek 11  Sat  Away       W
# 18        2022-10-26  21:00  Champions Lg     Group stage  Wed  Away       W
# 19        2022-10-29  15:30    Bundesliga    Matchweek 12  Sat  Home       W
# 20        2022-11-01  21:00  Champions Lg     Group stage  Tue  Home       W
# 21        2022-11-05  15:30    Bundesliga    Matchweek 13  Sat  Away       W
# 22        2022-11-08  20:30    Bundesliga    Matchweek 14  Tue  Home       W
# 23        2022-11-12  18:30    Bundesliga    Matchweek 15  Sat  Away       W
# 24        2023-01-20  20:30    Bundesliga    Matchweek 16  Fri  Away       D
# 25        2023-01-24  20:30    Bundesliga    Matchweek 17  Tue  Home       D
# 26        2023-01-28  18:30    Bundesliga    Matchweek 18  Sat  Home       D
# 27        2023-02-01  20:45     DFB-Pokal     Round of 16  Wed  Away       W
# 28        2023-02-05  17:30    Bundesliga    Matchweek 19  Sun  Away       W
# 29        2023-02-11  15:30    Bundesliga    Matchweek 20  Sat  Home       W
# 30        2023-02-14  21:00  Champions Lg     Round of 16  Tue  Away       W
# 31        2023-02-18  15:30    Bundesliga    Matchweek 21  Sat  Away       L
# 32        2023-02-26  17:30    Bundesliga    Matchweek 22  Sun  Home       W
# 33        2023-03-04  18:30    Bundesliga    Matchweek 23  Sat  Away       W
# 34        2023-03-08  21:00  Champions Lg     Round of 16  Wed  Home       W
# 35        2023-03-11  15:30    Bundesliga    Matchweek 24  Sat  Home       W
# 36        2023-03-19  17:30    Bundesliga    Matchweek 25  Sun  Away       L
# 37        2023-04-01  18:30    Bundesliga    Matchweek 26  Sat  Home       W
# 38        2023-04-04  20:45     DFB-Pokal  Quarter-finals  Tue  Home       L
# 39               NaN    NaN           NaN             NaN  NaN   NaN  28-7-4
#
#                                 ... Standard                Expected        \
#      GF  GA           Opponent  ...     Dist    FK PK PKatt       xG  npxG
# 0     5   3         RB Leipzig  ...      NaN   NaN  0     0      NaN   NaN
# 1     6   1     Eint Frankfurt  ...     16.6   1.0  0     0      4.0   4.0
# 2     2   0          Wolfsburg  ...     18.4   0.0  0     0      2.0   2.0
# 3     7   0             Bochum  ...     18.3   1.0  1     1      2.9   2.2
# 4     1   1         M'Gladbach  ...     17.4   1.0  0     0      2.8   2.8
# 5     5   0      Viktoria Köln  ...      NaN   NaN  0     0      NaN   NaN
# 6     1   1       Union Berlin  ...     18.1   0.0  0     0      1.5   1.5
# 7     2   0           it Inter  ...     18.7   1.0  0     0      2.5   2.5
# 8     2   2          Stuttgart  ...     17.5   1.0  0     0      2.2   2.2
# 9     2   0       es Barcelona  ...     17.7   0.0  0     0      1.7   1.7
# 10    0   1           Augsburg  ...     18.8   0.0  0     0      1.6   1.6
# 11    4   0         Leverkusen  ...     16.6   2.0  0     0      1.9   1.9
# 12    5   0  cz Viktoria Plzeň  ...     19.7   3.0  0     0      2.4   2.4
# 13    2   2           Dortmund  ...     20.5   0.0  0     0      0.6   0.6
# 14    4   2  cz Viktoria Plzeň  ...     16.3   0.0  0     0      3.0   3.0
# 15    5   0           Freiburg  ...     18.4   0.0  0     0      2.1   2.1
# 16    5   2           Augsburg  ...      NaN   NaN  0     0      NaN   NaN
# 17    2   0         Hoffenheim  ...     13.9   0.0  0     0      2.4   2.4
# 18    3   0       es Barcelona  ...     14.8   0.0  0     0      2.1   2.1
# 19    6   2           Mainz 05  ...     15.3   0.0  0     1      3.1   2.2
# 20    2   0           it Inter  ...     20.3   1.0  0     0      1.5   1.5
# 21    3   2         Hertha BSC  ...     17.1   1.0  0     0      1.9   1.9
# 22    6   1      Werder Bremen  ...     14.4   0.0  0     1      4.4   3.6
# 23    2   0         Schalke 04  ...     18.7   0.0  0     0      1.9   1.9
# 24    1   1         RB Leipzig  ...     13.9   0.0  0     0      0.7   0.7
# 25    1   1               Köln  ...     17.3   0.0  0     0      1.4   1.4
# 26    1   1     Eint Frankfurt  ...     17.9   0.0  0     0      1.6   1.6
# 27    4   0           Mainz 05  ...      NaN   NaN  0     0      NaN   NaN
# 28    4   2          Wolfsburg  ...     19.6   0.0  0     0      0.5   0.5
# 29    3   0             Bochum  ...     16.7   0.0  1     1      3.7   2.9
# 30    1   0       fr Paris S-G  ...     17.5   2.0  0     0      1.4   1.4
# 31    2   3         M'Gladbach  ...     18.4   0.0  0     0      1.1   1.1
# 32    3   0       Union Berlin  ...     13.8   0.0  0     0      3.6   3.6
# 33    2   1          Stuttgart  ...     14.9   0.0  0     0      2.1   2.1
# 34    2   0       fr Paris S-G  ...     14.6   0.0  0     0      1.7   1.7
# 35    5   3           Augsburg  ...     16.1   1.0  0     0      2.4   2.4
# 36    1   2         Leverkusen  ...     15.0   0.0  0     0      1.0   1.0
# 37    4   2           Dortmund  ...     16.5   0.0  0     0      2.4   2.4
# 38    1   2           Freiburg  ...      NaN   NaN  0     0      NaN   NaN
# 39  117  38                NaN  ...     17.1  15.0  2     4     71.9  68.8
#
#                          Unnamed: 25_level_0
#    npxG/Sh  G-xG np:G-xG        Match Report
# 0      NaN   NaN     NaN        Match Report
# 1     0.18   2.0     2.0        Match Report
# 2     0.09   0.0     0.0        Match Report
# 3     0.11   3.1     2.8        Match Report
# 4     0.09  -1.8    -1.8        Match Report
# 5      NaN   NaN     NaN        Match Report
# 6     0.07  -0.5    -0.5        Match Report
# 7     0.12  -1.5    -1.5        Match Report
# 8     0.12  -0.2    -0.2        Match Report
# 9     0.13   0.3     0.3        Match Report
# 10    0.09  -1.6    -1.6        Match Report
# 11    0.09   2.1     2.1        Match Report
# 12    0.12   2.6     2.6        Match Report
# 13    0.07   1.4     1.4        Match Report
# 14    0.20   1.0     1.0        Match Report
# 15    0.13   2.9     2.9        Match Report
# 16     NaN   NaN     NaN        Match Report
# 17    0.12  -0.4    -0.4        Match Report
# 18    0.16   0.9     0.9        Match Report
# 19    0.10   2.9     3.8        Match Report
# 20    0.07   0.5     0.5        Match Report
# 21    0.14   1.1     1.1        Match Report
# 22    0.18   1.6     2.4        Match Report
# 23    0.09   0.1     0.1        Match Report
# 24    0.10   0.3     0.3        Match Report
# 25    0.06  -0.4    -0.4        Match Report
# 26    0.12  -0.6    -0.6        Match Report
# 27     NaN   NaN     NaN        Match Report
# 28    0.06   3.5     3.5        Match Report
# 29    0.14  -0.7    -0.9        Match Report
# 30    0.08  -0.4    -0.4        Match Report
# 31    0.08   0.9     0.9        Match Report
# 32    0.18  -0.6    -0.6        Match Report
# 33    0.15  -0.1    -0.1        Match Report
# 34    0.14   0.3     0.3        Match Report
# 35    0.11   2.6     2.6        Match Report
# 36    0.09   0.0     0.0        Match Report
# 37    0.15   0.6     0.6        Match Report
# 38     NaN   NaN     NaN        Match Report
# 39    0.11  42.1    43.2                 NaN
#
# [40 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
team_data.head()
# Out:
#          Date   Time          Comp         Round  Day Venue Result   GF   GA  \
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
#
#          Opponent  ...  Formation          Referee  Match Report  Notes  Sh  \
# 0      RB Leipzig  ...    4-2-3-1  Robert Schröder  Match Report    NaN  12
# 1  Eint Frankfurt  ...      4-4-2    Deniz Aytekin  Match Report    NaN  23
# 2       Wolfsburg  ...    4-2-3-1      Harm Osmers  Match Report    NaN  24
# 3          Bochum  ...      4-4-2   Daniel Siebert  Match Report    NaN  21
# 4      M'Gladbach  ...    4-2-2-2  Daniel Schlager  Match Report    NaN  33
#
#   SoT  Dist   FK PK  PKatt
# 0   8   NaN  NaN  0      0
# 1  10  16.6  1.0  0      0
# 2   8  18.4  0.0  0      0
# 3  11  18.3  1.0  1      1
# 4  20  17.4  1.0  0      0
#
# [5 rows x 25 columns]

# %%
years = list(range(2023, 2021, -1))
years
# Out:
# [2023, 2022]

# %%
all_matches =[]

# %%
standings_url = "https://fbref.com/en/comps/8/Champions-League-Stats#all_rank_key"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[8]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
#     team_urls = team_urls[:8]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
      #  team_data = team_data[team_data["Comp"] == "Champions League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/53a2f082/2021-2022/Real-Madrid-Stats',
#  'https://fbref.com/en/squads/822bd0ba/2021-2022/Liverpool-Stats',
#  'https://fbref.com/en/squads/b8fd03ef/2021-2022/Manchester-City-Stats',
#  'https://fbref.com/en/squads/2a8183b3/2021-2022/Villarreal-Stats',
#  'https://fbref.com/en/squads/054efa67/2021-2022/Bayern-Munich-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/2021-2022/Chelsea-Stats',
#  'https://fbref.com/en/squads/a77c513e/2021-2022/Benfica-Stats',
#  'https://fbref.com/en/squads/db3b9613/2021-2022/Atletico-Madrid-Stats',
#  'https://fbref.com/en/squads/19c3f8c4/2021-2022/Ajax-Stats',
#  'https://fbref.com/en/squads/e0652b02/2021-2022/Juventus-Stats',
#  'https://fbref.com/en/squads/e2d8892c/2021-2022/Paris-Saint-Germain-Stats',
#  'https://fbref.com/en/squads/d609edc0/2021-2022/Internazionale-Stats',
#  'https://fbref.com/en/squads/19538871/2021-2022/Manchester-United-Stats',
#  'https://fbref.com/en/squads/cb188c0c/2021-2022/Lille-Stats',
#  'https://fbref.com/en/squads/50f2a074/2021-2022/Red-Bull-Salzburg-Stats',
#  'https://fbref.com/en/squads/13dc44fd/2021-2022/Sporting-CP-Stats',
#  'https://fbref.com/en/squads/add600ae/2021-2022/Dortmund-Stats',
#  'https://fbref.com/en/squads/acbb6a5b/2021-2022/RB-Leipzig-Stats',
#  'https://fbref.com/en/squads/50995c1e/2021-2022/Sheriff-Tiraspol-Stats',
#  'https://fbref.com/en/squads/206d90db/2021-2022/Barcelona-Stats',
#  'https://fbref.com/en/squads/ad2be733/2021-2022/Sevilla-Stats',
#  'https://fbref.com/en/squads/922493f3/2021-2022/Atalanta-Stats',
#  'https://fbref.com/en/squads/98ce363d/2021-2022/Zenit-Stats',
#  'https://fbref.com/en/squads/4b682260/2021-2022/Young-Boys-Stats',
#  'https://fbref.com/en/squads/4eaa11d7/2021-2022/Wolfsburg-Stats',
#  'https://fbref.com/en/squads/5e876ee6/2021-2022/Porto-Stats',
#  'https://fbref.com/en/squads/dc56fe14/2021-2022/Milan-Stats',
#  'https://fbref.com/en/squads/f1e6c5f1/2021-2022/Club-Brugge-Stats',
#  'https://fbref.com/en/squads/e89d5a28/2021-2022/Shakhtar-Donetsk-Stats',
#  'https://fbref.com/en/squads/c734e22f/2021-2022/Dynamo-Kyiv-Stats',
#  'https://fbref.com/en/squads/f3d8c8b9/2021-2022/Malmo-Stats',
#  'https://fbref.com/en/squads/0f9294bd/2021-2022/Besiktas-Stats']

# %%
len(all_matches)
# Out:
# 64

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time          comp         round  day venue result   gf   ga  \
# 0   2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1   2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2   2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3   2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4   2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..         ...    ...           ...           ...  ...   ...    ...  ...  ...
# 39  2022-04-25  20:30     Süper Lig  Matchweek 34  Mon  Home      L    0    3
# 40  2022-05-01  16:00     Süper Lig  Matchweek 35  Sun  Away      W    3    2
# 41  2022-05-08  19:00     Süper Lig  Matchweek 36  Sun  Home      D    1    1
# 42  2022-05-15  16:00     Süper Lig  Matchweek 37  Sun  Away      W    2    0
# 43  2022-05-21  19:00     Süper Lig  Matchweek 38  Sat  Home      D    1    1
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0       RB Leipzig  ...  Match Report    NaN  12.0   8.0   NaN  NaN  0     0
# 1   Eint Frankfurt  ...  Match Report    NaN  23.0  10.0  16.6  1.0  0     0
# 2        Wolfsburg  ...  Match Report    NaN  24.0   8.0  18.4  0.0  0     0
# 3           Bochum  ...  Match Report    NaN  21.0  11.0  18.3  1.0  1     1
# 4       M'Gladbach  ...  Match Report    NaN  33.0  20.0  17.4  1.0  0     0
# ..             ...  ...           ...    ...   ...   ...   ...  ... ..   ...
# 39       Kasımpaşa  ...  Match Report    NaN  15.0   3.0   NaN  NaN  0     0
# 40     Kayserispor  ...  Match Report    NaN  17.0   6.0   NaN  NaN  1     1
# 41      Fenerbahçe  ...  Match Report    NaN   9.0   3.0   NaN  NaN  1     2
# 42         Göztepe  ...  Match Report    NaN   8.0   3.0   NaN  NaN  0     0
# 43       Konyaspor  ...  Match Report    NaN  21.0   5.0   NaN  NaN  0     0
#
#    season           team
# 0    2023  Bayern Munich
# 1    2023  Bayern Munich
# 2    2023  Bayern Munich
# 3    2023  Bayern Munich
# 4    2023  Bayern Munich
# ..    ...            ...
# 39   2022       Besiktas
# 40   2022       Besiktas
# 41   2022       Besiktas
# 42   2022       Besiktas
# 43   2022       Besiktas
#
# [2664 rows x 27 columns]

# %%
match_df.to_csv("matches.csv")
