# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time          comp         round  day venue result   gf   ga  \
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0      RB Leipzig  ...  Match Report    NaN  12.0   8.0   NaN  NaN  0     0
# 1  Eint Frankfurt  ...  Match Report    NaN  23.0  10.0  16.6  1.0  0     0
# 2       Wolfsburg  ...  Match Report    NaN  24.0   8.0  18.4  0.0  0     0
# 3          Bochum  ...  Match Report    NaN  21.0  11.0  18.3  1.0  1     1
# 4      M'Gladbach  ...  Match Report    NaN  33.0  20.0  17.4  1.0  0     0
#
#   season           team
# 0   2023  Bayern Munich
# 1   2023  Bayern Munich
# 2   2023  Bayern Munich
# 3   2023  Bayern Munich
# 4   2023  Bayern Munich
#
# [5 rows x 27 columns]

# %%
selected_teams = ['Bayern Munich', 'Napoli', 'Benfica', 'Real Madrid', 'Bayern Munich', 'Napoli', 'Benfica', 'Real Madrid', 'Manchester City', 'Chelsea', 'Internazionale', 'Milan'] 
sm = selected_matches = matches[matches["team"].isin(selected_teams)]

# %%
sm
# Out:
#           date   time          comp         round  day venue result   gf   ga  \
# 0   2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1   2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2   2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3   2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4   2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..         ...    ...           ...           ...  ...   ...    ...  ...  ...
# 43  2022-04-24  20:45       Serie A  Matchweek 34  Sun  Away      W    2    1
# 44  2022-05-01  15:00       Serie A  Matchweek 35  Sun  Home      W    1    0
# 45  2022-05-08  20:45       Serie A  Matchweek 36  Sun  Away      W    3    1
# 46  2022-05-15  18:00       Serie A  Matchweek 37  Sun  Home      W    2    0
# 47  2022-05-22  18:00       Serie A  Matchweek 38  Sun  Away      W    3    0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0       RB Leipzig  ...  Match Report    NaN  12.0   8.0   NaN  NaN  0     0
# 1   Eint Frankfurt  ...  Match Report    NaN  23.0  10.0  16.6  1.0  0     0
# 2        Wolfsburg  ...  Match Report    NaN  24.0   8.0  18.4  0.0  0     0
# 3           Bochum  ...  Match Report    NaN  21.0  11.0  18.3  1.0  1     1
# 4       M'Gladbach  ...  Match Report    NaN  33.0  20.0  17.4  1.0  0     0
# ..             ...  ...           ...    ...   ...   ...   ...  ... ..   ...
# 43           Lazio  ...  Match Report    NaN  25.0   8.0  18.3  2.0  0     0
# 44      Fiorentina  ...  Match Report    NaN  13.0   2.0  15.0  0.0  0     0
# 45   Hellas Verona  ...  Match Report    NaN  18.0   8.0  17.8  0.0  0     0
# 46        Atalanta  ...  Match Report    NaN  12.0   6.0  21.5  1.0  0     0
# 47        Sassuolo  ...  Match Report    NaN  18.0  11.0  14.3  0.0  0     0
#
#    season           team
# 0    2023  Bayern Munich
# 1    2023  Bayern Munich
# 2    2023  Bayern Munich
# 3    2023  Bayern Munich
# 4    2023  Bayern Munich
# ..    ...            ...
# 43   2022          Milan
# 44   2022          Milan
# 45   2022          Milan
# 46   2022          Milan
# 47   2022          Milan
#
# [692 rows x 27 columns]

# %%
selected_teams
# Out:
# ['Bayern Munich',
#  'Napoli',
#  'Benfica',
#  'Real Madrid',
#  'Bayern Munich',
#  'Napoli',
#  'Benfica',
#  'Real Madrid',
#  'Manchester City',
#  'Chelsea',
#  'Internazionale',
#  'Milan']

# %%
sm["team"].value_counts()
# Out:
# Manchester City    102
# Chelsea            100
# Real Madrid         99
# Internazionale      93
# Benfica             87
# Milan               87
# Bayern Munich       86
# Napoli              38
# Name: team, dtype: int64

# %%
new_rows = pd.DataFrame({
    'date':['2004-03-11','2004-03-25', '2004-03-11', '2004-03-25', '2014-09-17', '2004-03-25', '2014-09-17-', '2004-03-25'],
    'time':['19:00', '19:00', '19:00', '19:00', '20:45', '19:45', '20:45', '19:45'],
    'comp':['UEFA cup', 'UEFA cup', 'UEFA cup', 'UEFA cup', 'Champions Lg', 'Champions Lg', 'Champions Lg', 'Champions Lg'],
    'round':['Fourth round', 'Fourth round', 'Fourth round', 'Fourth round', 'Group stage', 'Group stage','Group stage','Group stage'],
    'day': ['Thu', 'Thu', 'Thu', 'Thu', 'Wed', 'Tue', 'Wed', 'Tue'],
    'venue': ['Home', 'Away', 'Away', 'Home', 'Home', 'Away', 'Away', 'Home'],
    'result': ['D', 'L', 'D', 'W', 'W', 'L', 'L', 'W'], 
    'gf': ['0', '3', '0', '4', '1', '2', '0', '3'],
    'ga': ['0', '4', '0', '3', '0', '3', '1', '2'],
    'opponent': ['it Inter', 'it Inter', 'pt Benfica', 'pt Benfica', 'eng Manchaster City', 'eng Manchaster City', 'de Bayern Munich', 'de Bayern Munich'],
    'xg': ['0', '0', '0', '0', '0', '0', '0', '0'],
    'xga': ['0', '0', '0', '0', '0', '0', '0', '0'],
    'poss': ['0', '0', '0', '0', '58', '51', '42', '49'],
    'attendence': ['0', '0', '0', '0', '68000', '44510', '68000', '44510'],
    'captain': ['Jan Wegereef', 'Alain Sars', 'Jan Wegereef', 'Alain Sars', '0', '0', '0', '0'],
    'formation': ['3-4-1-2', '4-2-3-1', '4-2-3-1', '4-2-3-1', '4-2-3-1', '4-2-3-1', '4-4-1-1', '4-1-4-1'],
    'referee': ['Alain Sars', 'Jan Wegereef', 'Alain Sars', 'Jan Wegereef', 'Alberto Undiano', 'Pavel Královec', 'Alberto Undiano', 'Pavel Královec'], 
    'match report':['Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report'], 
    'sh': ['18', '12', '12', '20', '0', '0', '0', '0'], 
    'sot': ['3', '4', '4', '5', '0', '0', '0', '0'], 
    'dist': ['0', '0', '0', '0', '0', '0', '0', '0'], 
    'fk': ['0', '0', '0', '0', '0', '0', '0', '0'],
    'pk': ['0', '0', '0', '0', '0', '0', '0', '0'], 
    'pkatt': ['0', '0', '0', '0', '0', '0', '0', '0'],
    'season': ['2004', '2004', '2004', '2004', '2014', '2014', '2014', '2014'], 
    'team': ['Benefica', 'Benefica', 'Internazionale', 'Internazionale', 'Bayern Munich', 'Bayern Munich', 'Manchaster City', 'Manchaster City']
           })

sm = pd.concat([sm, new_rows], ignore_index=True)

# %%
# Data - date od match.
# Time - time of match.
# Comp - type of competition
# Round - round or phase of competition.
# Day - the day of the week on which the match took place.
# Venue - away (game played at an opponent's ground), home (game played on the home ground).
# Result - match result.
# GF - goals for.
# GA - goals against.
# Opponent - opposing team.
# Poss - possession of the ball.
# Attendance - number of people in the stadium.
# Captain - team captain.
# Formation - how players are positioned on the pitch.
# Referee - main referee of the match.
# Sh - shots total.
# SoT - shots on target.
# Dist - average shot distance.
# Fk - shots from free kicks.
# Pk - penalty kicks made.
# PKatt - penalty kicks attempted.

# %%
new_rows
# Out:
#           date   time          comp         round  day venue result gf ga  \
# 0   2004-03-11  19:00      UEFA cup  Fourth round  Thu  Home      D  0  0
# 1   2004-03-25  19:00      UEFA cup  Fourth round  Thu  Away      L  3  4
# 2   2004-03-11  19:00      UEFA cup  Fourth round  Thu  Away      D  0  0
# 3   2004-03-25  19:00      UEFA cup  Fourth round  Thu  Home      W  4  3
# 4   2014-09-17  20:45  Champions Lg   Group stage  Wed  Home      W  1  0
# 5   2004-03-25  19:45  Champions Lg   Group stage  Tue  Away      L  2  3
# 6  2014-09-17-  20:45  Champions Lg   Group stage  Wed  Away      L  0  1
# 7   2004-03-25  19:45  Champions Lg   Group stage  Tue  Home      W  3  2
#
#               opponent  ...          referee  match report  sh sot dist fk pk  \
# 0             it Inter  ...       Alain Sars  Match Report  18   3    0  0  0
# 1             it Inter  ...     Jan Wegereef  Match Report  12   4    0  0  0
# 2           pt Benfica  ...       Alain Sars  Match Report  12   4    0  0  0
# 3           pt Benfica  ...     Jan Wegereef  Match Report  20   5    0  0  0
# 4  eng Manchaster City  ...  Alberto Undiano  Match Report   0   0    0  0  0
# 5  eng Manchaster City  ...   Pavel Královec  Match Report   0   0    0  0  0
# 6     de Bayern Munich  ...  Alberto Undiano  Match Report   0   0    0  0  0
# 7     de Bayern Munich  ...   Pavel Královec  Match Report   0   0    0  0  0
#
#   pkatt season             team
# 0     0   2004         Benefica
# 1     0   2004         Benefica
# 2     0   2004   Internazionale
# 3     0   2004   Internazionale
# 4     0   2014    Bayern Munich
# 5     0   2014    Bayern Munich
# 6     0   2014  Manchaster City
# 7     0   2014  Manchaster City
#
# [8 rows x 26 columns]

# %%
sm[sm["team"] == "Manchester City"].sort_values("date")
# Out:
#            date   time              comp                round  day    venue  \
# 378  2021-08-07  17:15  Community Shield  FA Community Shield  Sat  Neutral
# 379  2021-08-15  16:30    Premier League          Matchweek 1  Sun     Away
# 380  2021-08-21  15:00    Premier League          Matchweek 2  Sat     Home
# 381  2021-08-28  12:30    Premier League          Matchweek 3  Sat     Home
# 382  2021-09-11  15:00    Premier League          Matchweek 4  Sat     Away
# ..          ...    ...               ...                  ...  ...      ...
# 198  2023-03-04  12:30    Premier League         Matchweek 26  Sat     Home
# 199  2023-03-11  17:30    Premier League         Matchweek 27  Sat     Away
# 200  2023-03-14  20:00      Champions Lg          Round of 16  Tue     Home
# 201  2023-03-18  17:45            FA Cup       Quarter-finals  Sat     Home
# 202  2023-04-01  12:30    Premier League         Matchweek 29  Sat     Home
#
#     result   gf   ga        opponent  ...                            notes  \
# 378      L    0    1  Leicester City  ...                              NaN
# 379      L    0    1       Tottenham  ...                              NaN
# 380      W    5    0    Norwich City  ...                              NaN
# 381      W    5    0         Arsenal  ...                              NaN
# 382      W    1    0  Leicester City  ...                              NaN
# ..     ...  ...  ...             ...  ...                              ...
# 198      W  2.0  0.0   Newcastle Utd  ...                              NaN
# 199      W  1.0  0.0  Crystal Palace  ...                              NaN
# 200      W  7.0  0.0   de RB Leipzig  ...  Leg 2 of 2; Manchester City won
# 201      W  6.0  0.0         Burnley  ...                              NaN
# 202      W  4.0  1.0       Liverpool  ...                              NaN
#
#        sh   sot  dist   fk pk pkatt season             team attendence
# 378  12.0   3.0   NaN  NaN  0     0   2022  Manchester City        NaN
# 379  18.0   4.0  17.3  1.0  0     0   2022  Manchester City        NaN
# 380  16.0   4.0  18.5  1.0  0     0   2022  Manchester City        NaN
# 381  25.0  10.0  14.8  0.0  0     0   2022  Manchester City        NaN
# 382  25.0   8.0  14.3  0.0  0     0   2022  Manchester City        NaN
# ..    ...   ...   ...  ... ..   ...    ...              ...        ...
# 198  11.0   3.0  15.8  2.0  0     0   2023  Manchester City        NaN
# 199  13.0   3.0  19.0  1.0  1     1   2023  Manchester City        NaN
# 200  22.0  14.0  13.1  0.0  1     1   2023  Manchester City        NaN
# 201  20.0  10.0   NaN  NaN  0     0   2023  Manchester City        NaN
# 202  17.0   8.0  14.5  1.0  0     0   2023  Manchester City        NaN
#
# [102 rows x 28 columns]

# %%
sm["round"].value_counts()
# Out:
# Group stage               94
# Round of 16               36
# Quarter-finals            21
# Semi-finals               17
# Matchweek 24              15
# Matchweek 21              15
# Matchweek 16              15
# Matchweek 17              15
# Matchweek 19              15
# Matchweek 20              15
# Matchweek 23              15
# Matchweek 22              15
# Matchweek 14              15
# Matchweek 1               15
# Matchweek 25              15
# Matchweek 26              15
# Matchweek 15              15
# Matchweek 18              15
# Matchweek 13              15
# Matchweek 7               15
# Matchweek 2               15
# Matchweek 3               15
# Matchweek 12              15
# Matchweek 5               15
# Matchweek 6               15
# Matchweek 4               15
# Matchweek 8               15
# Matchweek 10              15
# Matchweek 11              15
# Matchweek 9               15
# Matchweek 27              14
# Matchweek 29              12
# Matchweek 28              11
# Matchweek 30               7
# Matchweek 34               7
# Matchweek 33               7
# Matchweek 32               7
# Matchweek 31               7
# Fourth round               7
# Final                      6
# Matchweek 36               5
# Matchweek 35               5
# Matchweek 37               5
# Matchweek 38               5
# Third round proper         4
# Third round                4
# Play-off round             4
# Third qualifying round     4
# Round of 32                4
# Fourth round proper        3
# Fifth round proper         3
# Supercoppa Italiana        3
# FA Community Shield        2
# UEFA Super Cup             2
# Round of 64                2
# DFL-Supercup               2
# Name: round, dtype: int64

# %%
sm.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf               object
# ga               object
# opponent         object
# xg               object
# xga              object
# poss             object
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh               object
# sot              object
# dist             object
# fk               object
# pk               object
# pkatt            object
# season           object
# team             object
# attendence       object
# dtype: object

# %%
sm["date"] = pd.to_datetime(sm["date"])

# %%
sm.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                      object
# ga                      object
# opponent                object
# xg                      object
# xga                     object
# poss                    object
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                   object
# sh                      object
# sot                     object
# dist                    object
# fk                      object
# pk                      object
# pkatt                   object
# season                  object
# team                    object
# attendence              object
# dtype: object

# %%
sm["gf"] = pd.to_numeric(sm["gf"],errors = 'coerce')
sm["ga"] = pd.to_numeric(sm["gf"],errors = 'coerce')
sm["pk"] = sm["pk"].astype(float)
sm["pkatt"] = sm["pkatt"].astype(float)
sm.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                      object
# xga                     object
# poss                    object
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                   object
# sh                      object
# sot                     object
# dist                    object
# fk                      object
# pk                     float64
# pkatt                  float64
# season                  object
# team                    object
# attendence              object
# dtype: object

# %%
# converting from a string into categories --> and categories into numbers 
sm["venue_code"] = sm["venue"].astype("category").cat.codes
sm

# venue code:
# 0 --> Away
# 1 --> Home
# Out:
#           date   time          comp         round  day venue result   gf   ga  \
# 0   2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  5.0
# 1   2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  6.0
# 2   2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  2.0
# 3   2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  7.0
# 4   2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..         ...    ...           ...           ...  ...   ...    ...  ...  ...
# 695 2004-03-25  19:00      UEFA cup  Fourth round  Thu  Home      W  4.0  4.0
# 696 2014-09-17  20:45  Champions Lg   Group stage  Wed  Home      W  1.0  1.0
# 697 2004-03-25  19:45  Champions Lg   Group stage  Tue  Away      L  2.0  2.0
# 698 2014-09-17  20:45  Champions Lg   Group stage  Wed  Away      L  0.0  0.0
# 699 2004-03-25  19:45  Champions Lg   Group stage  Tue  Home      W  3.0  3.0
#
#                 opponent  ...    sh   sot  dist   fk   pk pkatt season  \
# 0             RB Leipzig  ...  12.0   8.0   NaN  NaN  0.0   0.0   2023
# 1         Eint Frankfurt  ...  23.0  10.0  16.6  1.0  0.0   0.0   2023
# 2              Wolfsburg  ...  24.0   8.0  18.4  0.0  0.0   0.0   2023
# 3                 Bochum  ...  21.0  11.0  18.3  1.0  1.0   1.0   2023
# 4             M'Gladbach  ...  33.0  20.0  17.4  1.0  0.0   0.0   2023
# ..                   ...  ...   ...   ...   ...  ...  ...   ...    ...
# 695           pt Benfica  ...    20     5     0    0  0.0   0.0   2004
# 696  eng Manchaster City  ...     0     0     0    0  0.0   0.0   2014
# 697  eng Manchaster City  ...     0     0     0    0  0.0   0.0   2014
# 698     de Bayern Munich  ...     0     0     0    0  0.0   0.0   2014
# 699     de Bayern Munich  ...     0     0     0    0  0.0   0.0   2014
#
#                 team attendence venue_code
# 0      Bayern Munich        NaN          0
# 1      Bayern Munich        NaN          0
# 2      Bayern Munich        NaN          1
# 3      Bayern Munich        NaN          0
# 4      Bayern Munich        NaN          1
# ..               ...        ...        ...
# 695   Internazionale          0          1
# 696    Bayern Munich      68000          1
# 697    Bayern Munich      44510          0
# 698  Manchaster City      68000          0
# 699  Manchaster City      44510          1
#
# [700 rows x 29 columns]

# %%
sm["opp_code"] = sm["opponent"].astype("category").cat.codes
sm
# Out:
#           date   time          comp         round  day venue result   gf   ga  \
# 0   2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  5.0
# 1   2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  6.0
# 2   2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  2.0
# 3   2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  7.0
# 4   2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..         ...    ...           ...           ...  ...   ...    ...  ...  ...
# 695 2004-03-25  19:00      UEFA cup  Fourth round  Thu  Home      W  4.0  4.0
# 696 2014-09-17  20:45  Champions Lg   Group stage  Wed  Home      W  1.0  1.0
# 697 2004-03-25  19:45  Champions Lg   Group stage  Tue  Away      L  2.0  2.0
# 698 2014-09-17  20:45  Champions Lg   Group stage  Wed  Away      L  0.0  0.0
# 699 2004-03-25  19:45  Champions Lg   Group stage  Tue  Home      W  3.0  3.0
#
#                 opponent  ...   sot  dist   fk   pk pkatt season  \
# 0             RB Leipzig  ...   8.0   NaN  NaN  0.0   0.0   2023
# 1         Eint Frankfurt  ...  10.0  16.6  1.0  0.0   0.0   2023
# 2              Wolfsburg  ...   8.0  18.4  0.0  0.0   0.0   2023
# 3                 Bochum  ...  11.0  18.3  1.0  1.0   1.0   2023
# 4             M'Gladbach  ...  20.0  17.4  1.0  0.0   0.0   2023
# ..                   ...  ...   ...   ...  ...  ...   ...    ...
# 695           pt Benfica  ...     5     0    0  0.0   0.0   2004
# 696  eng Manchaster City  ...     0     0    0  0.0   0.0   2014
# 697  eng Manchaster City  ...     0     0    0  0.0   0.0   2014
# 698     de Bayern Munich  ...     0     0    0  0.0   0.0   2014
# 699     de Bayern Munich  ...     0     0    0  0.0   0.0   2014
#
#                 team attendence venue_code opp_code
# 0      Bayern Munich        NaN          0       86
# 1      Bayern Munich        NaN          0       35
# 2      Bayern Munich        NaN          1      117
# 3      Bayern Munich        NaN          0       15
# 4      Bayern Munich        NaN          1       65
# ..               ...        ...        ...      ...
# 695   Internazionale          0          1      149
# 696    Bayern Munich      68000          1      131
# 697    Bayern Munich      44510          0      131
# 698  Manchaster City      68000          0      123
# 699  Manchaster City      44510          1      123
#
# [700 rows x 30 columns]

# %%
sm["hour"] = sm["time"].str.replace(":.+", "", regex=True).astype("int")
sm
# Out:
#           date   time          comp         round  day venue result   gf   ga  \
# 0   2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  5.0
# 1   2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  6.0
# 2   2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  2.0
# 3   2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  7.0
# 4   2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..         ...    ...           ...           ...  ...   ...    ...  ...  ...
# 695 2004-03-25  19:00      UEFA cup  Fourth round  Thu  Home      W  4.0  4.0
# 696 2014-09-17  20:45  Champions Lg   Group stage  Wed  Home      W  1.0  1.0
# 697 2004-03-25  19:45  Champions Lg   Group stage  Tue  Away      L  2.0  2.0
# 698 2014-09-17  20:45  Champions Lg   Group stage  Wed  Away      L  0.0  0.0
# 699 2004-03-25  19:45  Champions Lg   Group stage  Tue  Home      W  3.0  3.0
#
#                 opponent  ...  dist   fk   pk  pkatt season             team  \
# 0             RB Leipzig  ...   NaN  NaN  0.0    0.0   2023    Bayern Munich
# 1         Eint Frankfurt  ...  16.6  1.0  0.0    0.0   2023    Bayern Munich
# 2              Wolfsburg  ...  18.4  0.0  0.0    0.0   2023    Bayern Munich
# 3                 Bochum  ...  18.3  1.0  1.0    1.0   2023    Bayern Munich
# 4             M'Gladbach  ...  17.4  1.0  0.0    0.0   2023    Bayern Munich
# ..                   ...  ...   ...  ...  ...    ...    ...              ...
# 695           pt Benfica  ...     0    0  0.0    0.0   2004   Internazionale
# 696  eng Manchaster City  ...     0    0  0.0    0.0   2014    Bayern Munich
# 697  eng Manchaster City  ...     0    0  0.0    0.0   2014    Bayern Munich
# 698     de Bayern Munich  ...     0    0  0.0    0.0   2014  Manchaster City
# 699     de Bayern Munich  ...     0    0  0.0    0.0   2014  Manchaster City
#
#     attendence venue_code opp_code hour
# 0          NaN          0       86   20
# 1          NaN          0       35   20
# 2          NaN          1      117   17
# 3          NaN          0       15   17
# 4          NaN          1       65   18
# ..         ...        ...      ...  ...
# 695          0          1      149   19
# 696      68000          1      131   20
# 697      44510          0      131   19
# 698      68000          0      123   20
# 699      44510          1      123   19
#
# [700 rows x 31 columns]

# %%
sm["day_code"] = sm["date"].dt.dayofweek
sm

# Monday - 0
# Thuesday - 1
# ...
# Out:
#           date   time          comp         round  day venue result   gf   ga  \
# 0   2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  5.0
# 1   2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  6.0
# 2   2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  2.0
# 3   2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  7.0
# 4   2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..         ...    ...           ...           ...  ...   ...    ...  ...  ...
# 695 2004-03-25  19:00      UEFA cup  Fourth round  Thu  Home      W  4.0  4.0
# 696 2014-09-17  20:45  Champions Lg   Group stage  Wed  Home      W  1.0  1.0
# 697 2004-03-25  19:45  Champions Lg   Group stage  Tue  Away      L  2.0  2.0
# 698 2014-09-17  20:45  Champions Lg   Group stage  Wed  Away      L  0.0  0.0
# 699 2004-03-25  19:45  Champions Lg   Group stage  Tue  Home      W  3.0  3.0
#
#                 opponent  ...   fk   pk pkatt  season             team  \
# 0             RB Leipzig  ...  NaN  0.0   0.0    2023    Bayern Munich
# 1         Eint Frankfurt  ...  1.0  0.0   0.0    2023    Bayern Munich
# 2              Wolfsburg  ...  0.0  0.0   0.0    2023    Bayern Munich
# 3                 Bochum  ...  1.0  1.0   1.0    2023    Bayern Munich
# 4             M'Gladbach  ...  1.0  0.0   0.0    2023    Bayern Munich
# ..                   ...  ...  ...  ...   ...     ...              ...
# 695           pt Benfica  ...    0  0.0   0.0    2004   Internazionale
# 696  eng Manchaster City  ...    0  0.0   0.0    2014    Bayern Munich
# 697  eng Manchaster City  ...    0  0.0   0.0    2014    Bayern Munich
# 698     de Bayern Munich  ...    0  0.0   0.0    2014  Manchaster City
# 699     de Bayern Munich  ...    0  0.0   0.0    2014  Manchaster City
#
#     attendence venue_code opp_code hour day_code
# 0          NaN          0       86   20        5
# 1          NaN          0       35   20        4
# 2          NaN          1      117   17        6
# 3          NaN          0       15   17        6
# 4          NaN          1       65   18        5
# ..         ...        ...      ...  ...      ...
# 695          0          1      149   19        3
# 696      68000          1      131   20        2
# 697      44510          0      131   19        3
# 698      68000          0      123   20        2
# 699      44510          1      123   19        3
#
# [700 rows x 32 columns]

# %%
sm["target"] = (sm["result"] == "W").astype("int")
sm

# Lost [L] --> 0 
# Draw [D] --> 0
# Win [W] --> 1
# Out:
#           date   time          comp         round  day venue result   gf   ga  \
# 0   2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  5.0
# 1   2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  6.0
# 2   2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  2.0
# 3   2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  7.0
# 4   2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..         ...    ...           ...           ...  ...   ...    ...  ...  ...
# 695 2004-03-25  19:00      UEFA cup  Fourth round  Thu  Home      W  4.0  4.0
# 696 2014-09-17  20:45  Champions Lg   Group stage  Wed  Home      W  1.0  1.0
# 697 2004-03-25  19:45  Champions Lg   Group stage  Tue  Away      L  2.0  2.0
# 698 2014-09-17  20:45  Champions Lg   Group stage  Wed  Away      L  0.0  0.0
# 699 2004-03-25  19:45  Champions Lg   Group stage  Tue  Home      W  3.0  3.0
#
#                 opponent  ...   pk pkatt season             team attendence  \
# 0             RB Leipzig  ...  0.0   0.0   2023    Bayern Munich        NaN
# 1         Eint Frankfurt  ...  0.0   0.0   2023    Bayern Munich        NaN
# 2              Wolfsburg  ...  0.0   0.0   2023    Bayern Munich        NaN
# 3                 Bochum  ...  1.0   1.0   2023    Bayern Munich        NaN
# 4             M'Gladbach  ...  0.0   0.0   2023    Bayern Munich        NaN
# ..                   ...  ...  ...   ...    ...              ...        ...
# 695           pt Benfica  ...  0.0   0.0   2004   Internazionale          0
# 696  eng Manchaster City  ...  0.0   0.0   2014    Bayern Munich      68000
# 697  eng Manchaster City  ...  0.0   0.0   2014    Bayern Munich      44510
# 698     de Bayern Munich  ...  0.0   0.0   2014  Manchaster City      68000
# 699     de Bayern Munich  ...  0.0   0.0   2014  Manchaster City      44510
#
#     venue_code opp_code hour day_code target
# 0            0       86   20        5      1
# 1            0       35   20        4      1
# 2            1      117   17        6      1
# 3            0       15   17        6      1
# 4            1       65   18        5      0
# ..         ...      ...  ...      ...    ...
# 695          1      149   19        3      1
# 696          1      131   20        2      1
# 697          0      131   19        3      0
# 698          0      123   20        2      0
# 699          1      123   19        3      1
#
# [700 rows x 33 columns]

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\jchmi\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\jchmi\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\jchmi\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\jchmi\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jchmi\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.2.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: c:\users\jchmi\anaconda3\lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: scikit-learn-intelex

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = sm[sm["date"] < '2023-01-01']

# %%
test = sm[sm["date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)
acc
# Out:
# 0.5957446808510638

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0   1
# actual
# 0          15  45
# 1          12  69

# %%
from sklearn.metrics import precision_score
precision_score(test["target"], preds)
# Out:
# 0.6052631578947368

# %%
grouped_matches = sm.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
# 190 2023-01-27  20:00            FA Cup  Fourth round proper  Fri     Home
# 194 2023-02-18  15:00    Premier League         Matchweek 24  Sat     Away
# 195 2023-02-22  21:00      Champions Lg          Round of 16  Wed     Away
# 196 2023-02-25  17:30    Premier League         Matchweek 25  Sat     Away
# 197 2023-02-28  20:00            FA Cup   Fifth round proper  Tue     Away
# 201 2023-03-18  17:45            FA Cup       Quarter-finals  Sat     Home
#
#     result   gf   ga            opponent  ... day_code target gf_rolling  \
# 382      W  1.0  1.0      Leicester City  ...        5      1   3.333333
# 383      W  6.0  6.0       de RB Leipzig  ...        2      1   3.666667
# 384      D  0.0  0.0         Southampton  ...        5      0   4.000000
# 385      W  6.0  6.0             Wycombe  ...        1      1   2.333333
# 389      W  2.0  2.0             Burnley  ...        5      1   1.000000
# 390      W  5.0  5.0      be Club Brugge  ...        1      1   1.333333
# 391      W  4.0  4.0            Brighton  ...        5      1   3.000000
# 392      D  NaN  NaN            West Ham  ...        2      0   3.666667
# 396      W  3.0  3.0             Everton  ...        6      1   2.000000
# 397      W  2.0  2.0        fr Paris S-G  ...        2      1   3.000000
# 398      W  2.0  2.0            West Ham  ...        6      1   2.333333
# 399      W  2.0  2.0         Aston Villa  ...        2      1   2.333333
# 400      W  3.0  3.0             Watford  ...        5      1   2.000000
# 401      L  1.0  1.0       de RB Leipzig  ...        1      0   2.333333
# 402      W  1.0  1.0              Wolves  ...        5      1   2.000000
# 403      W  7.0  7.0        Leeds United  ...        1      1   1.666667
# 404      W  4.0  4.0       Newcastle Utd  ...        6      1   3.000000
# 405      W  6.0  6.0      Leicester City  ...        6      1   4.000000
# 406      W  1.0  1.0           Brentford  ...        2      1   5.666667
# 407      W  2.0  2.0             Arsenal  ...        5      1   3.666667
# 408      W  4.0  4.0        Swindon Town  ...        4      1   3.000000
# 415      L  2.0  2.0           Tottenham  ...        5      0   3.666667
# 416      W  1.0  1.0             Everton  ...        5      1   3.666667
# 417      W  2.0  2.0       P'borough Utd  ...        1      1   2.666667
# 421      W  4.0  4.0         Southampton  ...        6      1   1.333333
# 425      D  0.0  0.0  es Atlético Madrid  ...        2      0   1.666667
# 426      L  2.0  2.0           Liverpool  ...        5      0   1.000000
# 430      W  4.0  4.0        Leeds United  ...        5      1   4.000000
# 431      L  1.0  1.0      es Real Madrid  ...        2      0   4.333333
# 432      W  5.0  5.0       Newcastle Utd  ...        6      1   3.000000
# 433      W  5.0  5.0              Wolves  ...        2      1   3.333333
# 434      D  2.0  2.0            West Ham  ...        6      0   3.666667
# 435      W  3.0  3.0         Aston Villa  ...        6      1   4.000000
# 159      L  1.0  1.0           Liverpool  ...        5      0   3.333333
# 163      W  4.0  4.0      Crystal Palace  ...        5      1   3.000000
# 164      W  6.0  6.0     Nott'ham Forest  ...        2      1   3.666667
# 165      D  1.0  1.0         Aston Villa  ...        5      0   4.333333
# 166      W  4.0  4.0          es Sevilla  ...        1      1   3.666667
# 167      W  2.0  2.0         de Dortmund  ...        2      1   3.666667
# 168      W  3.0  3.0              Wolves  ...        5      1   2.333333
# 169      W  6.0  6.0      Manchester Utd  ...        6      1   3.000000
groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                         date   time          comp         round  day venue  \
# team
# Bayern Munich 437 2021-08-17  20:30  DFL-Supercup  DFL-Supercup  Tue  Away
#               443 2021-09-18  15:30    Bundesliga   Matchweek 5  Sat  Home
#               444 2021-09-24  20:30    Bundesliga   Matchweek 6  Fri  Away
#               445 2021-09-29  21:00  Champions Lg   Group stage  Wed  Home
#               446 2021-10-03  17:30    Bundesliga   Matchweek 7  Sun  Home
# ...                      ...    ...           ...           ...  ...   ...
# Real Madrid   151 2023-02-25  18:30       La Liga  Matchweek 23  Sat  Home
#               152 2023-03-02  21:00  Copa del Rey   Semi-finals  Thu  Home
#               156 2023-03-19  21:00       La Liga  Matchweek 26  Sun  Away
#               157 2023-04-02  16:15       La Liga  Matchweek 27  Sun  Home
#               158 2023-04-05  21:00  Copa del Rey   Semi-finals  Wed  Away
#
#                   result   gf   ga         opponent  ... day_code target  \
# team                                                 ...
# Bayern Munich 437      W  3.0  3.0         Dortmund  ...        1      1
#               443      W  7.0  7.0           Bochum  ...        5      1
#               444      W  3.0  3.0   Greuther Fürth  ...        4      1
#               445      W  5.0  5.0   ua Dynamo Kyiv  ...        2      1
#               446      L  1.0  1.0   Eint Frankfurt  ...        6      0
# ...                  ...  ...  ...              ...  ...      ...    ...
# Real Madrid   151      D  1.0  1.0  Atlético Madrid  ...        5      0
#               152      L  0.0  0.0        Barcelona  ...        3      0
#               156      L  1.0  1.0        Barcelona  ...        6      0
#               157      W  6.0  6.0       Valladolid  ...        6      1
#               158      W  4.0  4.0        Barcelona  ...        2      1
#
#                   gf_rolling  ga_rolling sh_rolling sot_rolling dist_rolling  \
# team
# Bayern Munich 437   1.333333    1.333333   7.000000    3.000000     4.133333
#               443   4.000000    4.000000  16.666667    6.000000    16.200000
#               444   4.666667    4.666667  19.333333    8.666667    16.366667
#               445   4.333333    4.333333  17.666667    8.333333    18.033333
#               446   5.000000    5.000000  19.000000    8.000000    18.200000
# ...                      ...         ...        ...         ...          ...
# Real Madrid   151   3.666667    3.666667  14.666667    7.666667    17.500000
#               152   2.666667    2.666667  12.666667    6.333333    17.900000
#               156   1.333333    1.333333  18.000000    6.333333    19.166667
#               157   1.666667    1.666667  16.666667    5.666667    19.866667
#               158   2.666667    2.666667  19.000000    9.000000    18.000000
#
#                   fk_rolling pk_rolling pkatt_rolling
# team
# Bayern Munich 437   0.000000   0.000000      0.000000
#               443   0.333333   0.333333      0.333333
#               444   0.666667   0.333333      0.333333
#               445   0.666667   0.000000      0.000000
#               446   0.666667   0.333333      0.333333
# ...                      ...        ...           ...
# Real Madrid   151   0.666667   0.666667      0.666667
#               152   0.000000   0.000000      0.000000
#               156   1.000000   0.000000      0.000000
#               157   0.666667   0.000000      0.000000
#               158   0.000000   0.000000      0.000000
#
# [489 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#           date   time          comp         round  day venue result   gf   ga  \
# 437 2021-08-17  20:30  DFL-Supercup  DFL-Supercup  Tue  Away      W  3.0  3.0
# 443 2021-09-18  15:30    Bundesliga   Matchweek 5  Sat  Home      W  7.0  7.0
# 444 2021-09-24  20:30    Bundesliga   Matchweek 6  Fri  Away      W  3.0  3.0
# 445 2021-09-29  21:00  Champions Lg   Group stage  Wed  Home      W  5.0  5.0
# 446 2021-10-03  17:30    Bundesliga   Matchweek 7  Sun  Home      L  1.0  1.0
# ..         ...    ...           ...           ...  ...   ...    ...  ...  ...
# 151 2023-02-25  18:30       La Liga  Matchweek 23  Sat  Home      D  1.0  1.0
# 152 2023-03-02  21:00  Copa del Rey   Semi-finals  Thu  Home      L  0.0  0.0
# 156 2023-03-19  21:00       La Liga  Matchweek 26  Sun  Away      L  1.0  1.0
# 157 2023-04-02  16:15       La Liga  Matchweek 27  Sun  Home      W  6.0  6.0
# 158 2023-04-05  21:00  Copa del Rey   Semi-finals  Wed  Away      W  4.0  4.0
#
#             opponent  ... day_code target gf_rolling  ga_rolling sh_rolling  \
# 437         Dortmund  ...        1      1   1.333333    1.333333   7.000000
# 443           Bochum  ...        5      1   4.000000    4.000000  16.666667
# 444   Greuther Fürth  ...        4      1   4.666667    4.666667  19.333333
# 445   ua Dynamo Kyiv  ...        2      1   4.333333    4.333333  17.666667
# 446   Eint Frankfurt  ...        6      0   5.000000    5.000000  19.000000
# ..               ...  ...      ...    ...        ...         ...        ...
# 151  Atlético Madrid  ...        5      0   3.666667    3.666667  14.666667
# 152        Barcelona  ...        3      0   2.666667    2.666667  12.666667
# 156        Barcelona  ...        6      0   1.333333    1.333333  18.000000
# 157       Valladolid  ...        6      1   1.666667    1.666667  16.666667
# 158        Barcelona  ...        2      1   2.666667    2.666667  19.000000
#
#     sot_rolling dist_rolling fk_rolling pk_rolling pkatt_rolling
# 437    3.000000     4.133333   0.000000   0.000000      0.000000
# 443    6.000000    16.200000   0.333333   0.333333      0.333333
# 444    8.666667    16.366667   0.666667   0.333333      0.333333
# 445    8.333333    18.033333   0.666667   0.000000      0.000000
# 446    8.000000    18.200000   0.666667   0.333333      0.333333
# ..          ...          ...        ...        ...           ...
# 151    7.666667    17.500000   0.666667   0.666667      0.666667
# 152    6.333333    17.900000   0.000000   0.000000      0.000000
# 156    6.333333    19.166667   1.000000   0.000000      0.000000
# 157    5.666667    19.866667   0.666667   0.000000      0.000000
# 158    9.000000    18.000000   0.000000   0.000000      0.000000
#
# [489 rows x 41 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#           date   time          comp         round  day venue result   gf   ga  \
# 0   2021-08-17  20:30  DFL-Supercup  DFL-Supercup  Tue  Away      W  3.0  3.0
# 1   2021-09-18  15:30    Bundesliga   Matchweek 5  Sat  Home      W  7.0  7.0
# 2   2021-09-24  20:30    Bundesliga   Matchweek 6  Fri  Away      W  3.0  3.0
# 3   2021-09-29  21:00  Champions Lg   Group stage  Wed  Home      W  5.0  5.0
# 4   2021-10-03  17:30    Bundesliga   Matchweek 7  Sun  Home      L  1.0  1.0
# ..         ...    ...           ...           ...  ...   ...    ...  ...  ...
# 484 2023-02-25  18:30       La Liga  Matchweek 23  Sat  Home      D  1.0  1.0
# 485 2023-03-02  21:00  Copa del Rey   Semi-finals  Thu  Home      L  0.0  0.0
# 486 2023-03-19  21:00       La Liga  Matchweek 26  Sun  Away      L  1.0  1.0
# 487 2023-04-02  16:15       La Liga  Matchweek 27  Sun  Home      W  6.0  6.0
# 488 2023-04-05  21:00  Copa del Rey   Semi-finals  Wed  Away      W  4.0  4.0
#
#             opponent  ... day_code target gf_rolling  ga_rolling sh_rolling  \
# 0           Dortmund  ...        1      1   1.333333    1.333333   7.000000
# 1             Bochum  ...        5      1   4.000000    4.000000  16.666667
# 2     Greuther Fürth  ...        4      1   4.666667    4.666667  19.333333
# 3     ua Dynamo Kyiv  ...        2      1   4.333333    4.333333  17.666667
# 4     Eint Frankfurt  ...        6      0   5.000000    5.000000  19.000000
# ..               ...  ...      ...    ...        ...         ...        ...
# 484  Atlético Madrid  ...        5      0   3.666667    3.666667  14.666667
# 485        Barcelona  ...        3      0   2.666667    2.666667  12.666667
# 486        Barcelona  ...        6      0   1.333333    1.333333  18.000000
# 487       Valladolid  ...        6      1   1.666667    1.666667  16.666667
# 488        Barcelona  ...        2      1   2.666667    2.666667  19.000000
#
#     sot_rolling dist_rolling fk_rolling pk_rolling pkatt_rolling
# 0      3.000000     4.133333   0.000000   0.000000      0.000000
# 1      6.000000    16.200000   0.333333   0.333333      0.333333
# 2      8.666667    16.366667   0.666667   0.333333      0.333333
# 3      8.333333    18.033333   0.666667   0.000000      0.000000
# 4      8.000000    18.200000   0.666667   0.333333      0.333333
# ..          ...          ...        ...        ...           ...
# 484    7.666667    17.500000   0.666667   0.666667      0.666667
# 485    6.333333    17.900000   0.000000   0.000000      0.000000
# 486    6.333333    19.166667   1.000000   0.000000      0.000000
# 487    5.666667    19.866667   0.666667   0.000000      0.000000
# 488    9.000000    18.000000   0.000000   0.000000      0.000000
#
# [489 rows x 41 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.5930232558139535

# %%
combined
# Out:
#      actual  predicted
# 53        0          1
# 54        0          1
# 55        0          1
# 56        1          1
# 57        0          1
# ..      ...        ...
# 484       0          1
# 485       0          1
# 486       0          1
# 487       1          1
# 488       1          1
#
# [94 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined
# Out:
#      actual  predicted       date           team         opponent result
# 53        0          1 2023-01-20  Bayern Munich       RB Leipzig      D
# 54        0          1 2023-01-24  Bayern Munich             Köln      D
# 55        0          1 2023-01-28  Bayern Munich   Eint Frankfurt      D
# 56        1          1 2023-02-01  Bayern Munich         Mainz 05      W
# 57        0          1 2023-02-18  Bayern Munich       M'Gladbach      L
# ..      ...        ...        ...            ...              ...    ...
# 484       0          1 2023-02-25    Real Madrid  Atlético Madrid      D
# 485       0          1 2023-03-02    Real Madrid        Barcelona      L
# 486       0          1 2023-03-19    Real Madrid        Barcelona      L
# 487       1          1 2023-04-02    Real Madrid       Valladolid      W
# 488       1          1 2023-04-05    Real Madrid        Barcelona      W
#
# [94 rows x 6 columns]

# %%
combined.head(10)
# Out:
#     actual  predicted       date           team        opponent result
# 53       0          1 2023-01-20  Bayern Munich      RB Leipzig      D
# 54       0          1 2023-01-24  Bayern Munich            Köln      D
# 55       0          1 2023-01-28  Bayern Munich  Eint Frankfurt      D
# 56       1          1 2023-02-01  Bayern Munich        Mainz 05      W
# 57       0          1 2023-02-18  Bayern Munich      M'Gladbach      L
# 58       1          1 2023-02-26  Bayern Munich    Union Berlin      W
# 59       1          1 2023-03-04  Bayern Munich       Stuttgart      W
# 60       1          1 2023-03-08  Bayern Munich    fr Paris S-G      W
# 61       1          1 2023-03-11  Bayern Munich        Augsburg      W
# 62       0          1 2023-03-19  Bayern Munich      Leverkusen      L
