# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time          comp         round  day venue result   gf   ga
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0  \
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt
# 0      RB Leipzig  ...  Match Report    NaN  12.0   8.0   NaN  NaN  0     0  \
# 1  Eint Frankfurt  ...  Match Report    NaN  23.0  10.0  16.6  1.0  0     0
# 2       Wolfsburg  ...  Match Report    NaN  24.0   8.0  18.4  0.0  0     0
# 3          Bochum  ...  Match Report    NaN  21.0  11.0  18.3  1.0  1     1
# 4      M'Gladbach  ...  Match Report    NaN  33.0  20.0  17.4  1.0  0     0
#
#   season           team
# ...

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf               object
# ga               object
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches["gf"] = pd.to_numeric(matches["gf"],errors = 'coerce')
matches["ga"] = pd.to_numeric(matches["gf"],errors = 'coerce')
matches["pk"] = matches["pk"].astype(float)
matches["pkatt"] = matches["pkatt"].astype(float)
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                   object
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
matches["day_code"] = matches["date"].dt.dayofweek
matches

# Monday - 0
# Thuesday - 1
# ...
# Out:
#          date   time          comp         round  day venue result   gf   ga
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  5.0  \
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  6.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  2.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  7.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..        ...    ...           ...           ...  ...   ...    ...  ...  ...
# 39 2022-04-25  20:30     Süper Lig  Matchweek 34  Mon  Home      L  0.0  0.0
# 40 2022-05-01  16:00     Süper Lig  Matchweek 35  Sun  Away      W  3.0  3.0
# 41 2022-05-08  19:00     Süper Lig  Matchweek 36  Sun  Home      D  1.0  1.0
# 42 2022-05-15  16:00     Süper Lig  Matchweek 37  Sun  Away      W  2.0  2.0
# 43 2022-05-21  19:00     Süper Lig  Matchweek 38  Sat  Home      D  1.0  1.0
#
# ...

# %%
selected_teams = ['Bayern Munich', 'Napoli', 'Benfica', 'Real Madrid', 'Bayern Munich', 'Napoli', 'Benfica', 'Real Madrid', 'Manchester City', 'Chelsea', 'Internazionale', 'Milan'] 
selected_teams
# Out:
# ['Bayern Munich',
#  'Napoli',
#  'Benfica',
#  'Real Madrid',
#  'Bayern Munich',
#  'Napoli',
#  'Benfica',
#  'Real Madrid',
#  'Manchester City',
#  'Chelsea',
#  'Internazionale',
#  'Milan']

# %%
selected_matches = matches[matches["team"].isin(selected_teams)]
selected_matches
# Out:
#          date   time          comp         round  day venue result   gf   ga
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  5.0  \
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  6.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  2.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  7.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# ..        ...    ...           ...           ...  ...   ...    ...  ...  ...
# 43 2022-04-24  20:45       Serie A  Matchweek 34  Sun  Away      W  2.0  2.0
# 44 2022-05-01  15:00       Serie A  Matchweek 35  Sun  Home      W  1.0  1.0
# 45 2022-05-08  20:45       Serie A  Matchweek 36  Sun  Away      W  3.0  3.0
# 46 2022-05-15  18:00       Serie A  Matchweek 37  Sun  Home      W  2.0  2.0
# 47 2022-05-22  18:00       Serie A  Matchweek 38  Sun  Away      W  3.0  3.0
#
# ...

# %%
selected_matches["team"].value_counts()
# Out:
# team
# Manchester City    102
# Chelsea            100
# Real Madrid         99
# Internazionale      93
# Benfica             87
# Milan               87
# Bayern Munich       86
# Napoli              38
# Name: count, dtype: int64

# %%
new_rows = pd.DataFrame({
    'date':['2004-03-11','2004-03-25', '2004-03-11', '2004-03-25', '2014-09-17', '2004-03-25', '2014-09-17-', '2004-03-25'],
    'time':['19:00', '19:00', '19:00', '19:00', '20:45', '19:45', '20:45', '19:45'],
    'comp':['UEFA cup', 'UEFA cup', 'UEFA cup', 'UEFA cup', 'Champions Lg', 'Champions Lg', 'Champions Lg', 'Champions Lg'],
    'round':['Fourth round', 'Fourth round', 'Fourth round', 'Fourth round', 'Group stage', 'Group stage','Group stage','Group stage'],
    'day': ['Thu', 'Thu', 'Thu', 'Thu', 'Wed', 'Tue', 'Wed', 'Tue'],
    'venue': ['Home', 'Away', 'Away', 'Home', 'Home', 'Away', 'Away', 'Home'],
    'result': ['D', 'L', 'D', 'W', 'W', 'L', 'L', 'W'], 
    'gf': ['0', '3', '0', '4', '1', '2', '0', '3'],
    'ga': ['0', '4', '0', '3', '0', '3', '1', '2'],
    'opponent': ['it Inter', 'it Inter', 'pt Benfica', 'pt Benfica', 'eng Manchaster City', 'eng Manchaster City', 'de Bayern Munich', 'de Bayern Munich'],
    'xg': ['0', '0', '0', '0', '0', '0', '0', '0'],
    'xga': ['0', '0', '0', '0', '0', '0', '0', '0'],
    'poss': ['0', '0', '0', '0', '58', '51', '42', '49'],
    'attendence': ['0', '0', '0', '0', '68000', '44510', '68000', '44510'],
    'captain': ['Jan Wegereef', 'Alain Sars', 'Jan Wegereef', 'Alain Sars', '0', '0', '0', '0'],
    'formation': ['3-4-1-2', '4-2-3-1', '4-2-3-1', '4-2-3-1', '4-2-3-1', '4-2-3-1', '4-4-1-1', '4-1-4-1'],
    'referee': ['Alain Sars', 'Jan Wegereef', 'Alain Sars', 'Jan Wegereef', 'Alberto Undiano', 'Pavel Královec', 'Alberto Undiano', 'Pavel Královec'], 
    'match report':['Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report'], 
    'sh': ['18', '12', '12', '20', '0', '0', '0', '0'], 
    'sot': ['3', '4', '4', '5', '0', '0', '0', '0'], 
    'dist': ['0', '0', '0', '0', '0', '0', '0', '0'], 
    'fk': ['0', '0', '0', '0', '0', '0', '0', '0'],
    'pk': ['0', '0', '0', '0', '0', '0', '0', '0'], 
    'pkatt': ['0', '0', '0', '0', '0', '0', '0', '0'],
    'season': ['2004', '2004', '2004', '2004', '2014', '2014', '2014', '2014'], 
    'team': ['Benefica', 'Benefica', 'Internazionale', 'Internazionale', 'Bayern Munich', 'Bayern Munich', 'Manchaster City', 'Manchaster City']
           })

selected_matches = pd.concat([selected_matches, new_rows], ignore_index=True)

# %%
# Data - date od match.
# Time - time of match.
# Comp - type of competition
# Round - round or phase of competition.
# Day - the day of the week on which the match took place.
# Venue - away (game played at an opponent's ground), home (game played on the home ground).
# Result - match result.
# GF - goals for.
# GA - goals against.
# Opponent - opposing team.
# Poss - possession of the ball.
# Attendance - number of people in the stadium.
# Captain - team captain.
# Formation - how players are positioned on the pitch.
# Referee - main referee of the match.
# Sh - shots total.
# SoT - shots on target.
# Dist - average shot distance.
# Fk - shots from free kicks.
# Pk - penalty kicks made.
# PKatt - penalty kicks attempted.

# %%
new_rows
# Out:
#           date   time          comp         round  day venue result gf ga
# 0   2004-03-11  19:00      UEFA cup  Fourth round  Thu  Home      D  0  0  \
# 1   2004-03-25  19:00      UEFA cup  Fourth round  Thu  Away      L  3  4
# 2   2004-03-11  19:00      UEFA cup  Fourth round  Thu  Away      D  0  0
# 3   2004-03-25  19:00      UEFA cup  Fourth round  Thu  Home      W  4  3
# 4   2014-09-17  20:45  Champions Lg   Group stage  Wed  Home      W  1  0
# 5   2004-03-25  19:45  Champions Lg   Group stage  Tue  Away      L  2  3
# 6  2014-09-17-  20:45  Champions Lg   Group stage  Wed  Away      L  0  1
# 7   2004-03-25  19:45  Champions Lg   Group stage  Tue  Home      W  3  2
#
#               opponent  ...          referee  match report  sh sot dist fk pk
# 0             it Inter  ...       Alain Sars  Match Report  18   3    0  0  0  \
# 1             it Inter  ...     Jan Wegereef  Match Report  12   4    0  0  0
# ...

# %%
selected_matches[selected_matches["team"] == "Manchester City"].sort_values("date")
# Out:
#                     date   time              comp                round  day
# 378  2021-08-07 00:00:00  17:15  Community Shield  FA Community Shield  Sat  \
# 379  2021-08-15 00:00:00  16:30    Premier League          Matchweek 1  Sun
# 380  2021-08-21 00:00:00  15:00    Premier League          Matchweek 2  Sat
# 381  2021-08-28 00:00:00  12:30    Premier League          Matchweek 3  Sat
# 382  2021-09-11 00:00:00  15:00    Premier League          Matchweek 4  Sat
# ..                   ...    ...               ...                  ...  ...
# 198  2023-03-04 00:00:00  12:30    Premier League         Matchweek 26  Sat
# 199  2023-03-11 00:00:00  17:30    Premier League         Matchweek 27  Sat
# 200  2023-03-14 00:00:00  20:00      Champions Lg          Round of 16  Tue
# 201  2023-03-18 00:00:00  17:45            FA Cup       Quarter-finals  Sat
# 202  2023-04-01 00:00:00  12:30    Premier League         Matchweek 29  Sat
#
# ...

# %%
selected_matches["round"].value_counts()
# Out:
# round
# Group stage               94
# Round of 16               36
# Quarter-finals            21
# Semi-finals               17
# Matchweek 24              15
# Matchweek 21              15
# Matchweek 16              15
# Matchweek 17              15
# Matchweek 19              15
# Matchweek 20              15
# Matchweek 23              15
# Matchweek 22              15
# Matchweek 14              15
# Matchweek 1               15
# Matchweek 25              15
# Matchweek 26              15
# Matchweek 15              15
# Matchweek 18              15
# Matchweek 13              15
# Matchweek 7               15
# Matchweek 2               15
# Matchweek 3               15
# Matchweek 12              15
# Matchweek 5               15
# Matchweek 6               15
# Matchweek 4               15
# Matchweek 8               15
# Matchweek 10              15
# Matchweek 11              15
# Matchweek 9               15
# Matchweek 27              14
# Matchweek 29              12
# ...

# %%
selected_matches["target"] = (selected_matches["result"] == "W").astype("int")
selected_matches

# Lost [L] --> 0 
# Draw [D] --> 0
# Win [W] --> 1
# Out:
#                     date   time          comp         round  day venue result
# 0    2022-07-30 00:00:00  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  \
# 1    2022-08-05 00:00:00  20:30    Bundesliga   Matchweek 1  Fri  Away      W
# 2    2022-08-14 00:00:00  17:30    Bundesliga   Matchweek 2  Sun  Home      W
# 3    2022-08-21 00:00:00  17:30    Bundesliga   Matchweek 3  Sun  Away      W
# 4    2022-08-27 00:00:00  18:30    Bundesliga   Matchweek 4  Sat  Home      D
# ..                   ...    ...           ...           ...  ...   ...    ...
# 695           2004-03-25  19:00      UEFA cup  Fourth round  Thu  Home      W
# 696           2014-09-17  20:45  Champions Lg   Group stage  Wed  Home      W
# 697           2004-03-25  19:45  Champions Lg   Group stage  Tue  Away      L
# 698          2014-09-17-  20:45  Champions Lg   Group stage  Wed  Away      L
# 699           2004-03-25  19:45  Champions Lg   Group stage  Tue  Home      W
#
# ...

# %%
# converting from a string into categories --> and categories into numbers 
selected_matches["venue_code"] = selected_matches["venue"].astype("category").cat.codes
selected_matches

# venue code:
# 0 --> Away
# 1 --> Home
# Out:
#                     date   time          comp         round  day venue result
# 0    2022-07-30 00:00:00  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  \
# 1    2022-08-05 00:00:00  20:30    Bundesliga   Matchweek 1  Fri  Away      W
# 2    2022-08-14 00:00:00  17:30    Bundesliga   Matchweek 2  Sun  Home      W
# 3    2022-08-21 00:00:00  17:30    Bundesliga   Matchweek 3  Sun  Away      W
# 4    2022-08-27 00:00:00  18:30    Bundesliga   Matchweek 4  Sat  Home      D
# ..                   ...    ...           ...           ...  ...   ...    ...
# 695           2004-03-25  19:00      UEFA cup  Fourth round  Thu  Home      W
# 696           2014-09-17  20:45  Champions Lg   Group stage  Wed  Home      W
# 697           2004-03-25  19:45  Champions Lg   Group stage  Tue  Away      L
# 698          2014-09-17-  20:45  Champions Lg   Group stage  Wed  Away      L
# 699           2004-03-25  19:45  Champions Lg   Group stage  Tue  Home      W
#
# ...

# %%
selected_matches["opp_code"] = selected_matches["opponent"].astype("category").cat.codes
selected_matches
# Out:
#                     date   time          comp         round  day venue result
# 0    2022-07-30 00:00:00  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  \
# 1    2022-08-05 00:00:00  20:30    Bundesliga   Matchweek 1  Fri  Away      W
# 2    2022-08-14 00:00:00  17:30    Bundesliga   Matchweek 2  Sun  Home      W
# 3    2022-08-21 00:00:00  17:30    Bundesliga   Matchweek 3  Sun  Away      W
# 4    2022-08-27 00:00:00  18:30    Bundesliga   Matchweek 4  Sat  Home      D
# ..                   ...    ...           ...           ...  ...   ...    ...
# 695           2004-03-25  19:00      UEFA cup  Fourth round  Thu  Home      W
# 696           2014-09-17  20:45  Champions Lg   Group stage  Wed  Home      W
# 697           2004-03-25  19:45  Champions Lg   Group stage  Tue  Away      L
# 698          2014-09-17-  20:45  Champions Lg   Group stage  Wed  Away      L
# 699           2004-03-25  19:45  Champions Lg   Group stage  Tue  Home      W
#
# ...

# %%
selected_matches["hour"] = selected_matches["time"].str.replace(":.+", "", regex=True).astype("int")
selected_matches
# Out:
#                     date   time          comp         round  day venue result
# 0    2022-07-30 00:00:00  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  \
# 1    2022-08-05 00:00:00  20:30    Bundesliga   Matchweek 1  Fri  Away      W
# 2    2022-08-14 00:00:00  17:30    Bundesliga   Matchweek 2  Sun  Home      W
# 3    2022-08-21 00:00:00  17:30    Bundesliga   Matchweek 3  Sun  Away      W
# 4    2022-08-27 00:00:00  18:30    Bundesliga   Matchweek 4  Sat  Home      D
# ..                   ...    ...           ...           ...  ...   ...    ...
# 695           2004-03-25  19:00      UEFA cup  Fourth round  Thu  Home      W
# 696           2014-09-17  20:45  Champions Lg   Group stage  Wed  Home      W
# 697           2004-03-25  19:45  Champions Lg   Group stage  Tue  Away      L
# 698          2014-09-17-  20:45  Champions Lg   Group stage  Wed  Away      L
# 699           2004-03-25  19:45  Champions Lg   Group stage  Tue  Home      W
#
# ...

# %%
# !pip install -U scikit-learn

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.2.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: imbalanced-learn

# %%
from sklearn.ensemble import RandomForestClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 from sklearn.ensemble import RandomForestClassifier
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/__init__.py:5
#       1 """
#       2 The :mod:`sklearn.ensemble` module includes ensemble-based methods for
#       3 classification, regression and anomaly detection.
#       4 """
# ----> 5 from ._base import BaseEnsemble
#       6 from ._forest import RandomForestClassifier
#       7 from ._forest import RandomForestRegressor
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_base.py:18
#      16 from ..base import BaseEstimator
#      17 from ..base import MetaEstimatorMixin
# ---> 18 from ..tree import (
#      19     DecisionTreeRegressor,
#      20     BaseDecisionTree,
# ...

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
train = sm[sm["date"] < '2023-01-01']

# %%
test = sm[sm["date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 rf.fit(train[predictors], train["target"])
#
# NameError: name 'rf' is not defined

# %%
preds = rf.predict(test[predictors])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 preds = rf.predict(test[predictors])
#
# NameError: name 'rf' is not defined

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)
acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 acc = accuracy_score(test["target"], preds)
#       2 acc
#
# NameError: name 'preds' is not defined

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))
#
# NameError: name 'preds' is not defined

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 pd.crosstab(index=combined["actual"], columns=combined["predicted"])
#
# NameError: name 'combined' is not defined

# %%
from sklearn.metrics import precision_score
precision_score(test["target"], preds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 2
#       1 from sklearn.metrics import precision_score
# ----> 2 precision_score(test["target"], preds)
#
# NameError: name 'preds' is not defined

# %%
grouped_matches = sm.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#            date   time              comp                round  day    venue
# 382  2021-09-11  15:00    Premier League          Matchweek 4  Sat     Away  \
# 383  2021-09-15  20:00      Champions Lg          Group stage  Wed     Home
# 384  2021-09-18  15:00    Premier League          Matchweek 5  Sat     Home
# 385  2021-09-21  19:45           EFL Cup          Third round  Tue     Home
# 389  2021-10-16  15:00    Premier League          Matchweek 8  Sat     Home
# 390  2021-10-19  18:45      Champions Lg          Group stage  Tue     Away
# 391  2021-10-23  17:30    Premier League          Matchweek 9  Sat     Away
# 392  2021-10-27  19:45           EFL Cup         Fourth round  Wed     Away
# 396  2021-11-21  14:00    Premier League         Matchweek 12  Sun     Home
# 397  2021-11-24  20:00      Champions Lg          Group stage  Wed     Home
# 398  2021-11-28  14:00    Premier League         Matchweek 13  Sun     Home
# ...

# %%
matches_rolling = sm.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                          date   time          comp         round  day venue
# team
# Bayern Munich 437  2021-08-17  20:30  DFL-Supercup  DFL-Supercup  Tue  Away  \
#               443  2021-09-18  15:30    Bundesliga   Matchweek 5  Sat  Home
#               444  2021-09-24  20:30    Bundesliga   Matchweek 6  Fri  Away
#               445  2021-09-29  21:00  Champions Lg   Group stage  Wed  Home
#               446  2021-10-03  17:30    Bundesliga   Matchweek 7  Sun  Home
# ...                       ...    ...           ...           ...  ...   ...
# Real Madrid   151  2023-02-25  18:30       La Liga  Matchweek 23  Sat  Home
#               152  2023-03-02  21:00  Copa del Rey   Semi-finals  Thu  Home
#               156  2023-03-19  21:00       La Liga  Matchweek 26  Sun  Away
#               157  2023-04-02  16:15       La Liga  Matchweek 27  Sun  Home
#               158  2023-04-05  21:00  Copa del Rey   Semi-finals  Wed  Away
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#            date   time          comp         round  day venue result   gf
# 437  2021-08-17  20:30  DFL-Supercup  DFL-Supercup  Tue  Away      W  3.0  \
# 443  2021-09-18  15:30    Bundesliga   Matchweek 5  Sat  Home      W  7.0
# 444  2021-09-24  20:30    Bundesliga   Matchweek 6  Fri  Away      W  3.0
# 445  2021-09-29  21:00  Champions Lg   Group stage  Wed  Home      W  5.0
# 446  2021-10-03  17:30    Bundesliga   Matchweek 7  Sun  Home      L  1.0
# ..          ...    ...           ...           ...  ...   ...    ...  ...
# 151  2023-02-25  18:30       La Liga  Matchweek 23  Sat  Home      D  1.0
# 152  2023-03-02  21:00  Copa del Rey   Semi-finals  Thu  Home      L  0.0
# 156  2023-03-19  21:00       La Liga  Matchweek 26  Sun  Away      L  1.0
# 157  2023-04-02  16:15       La Liga  Matchweek 27  Sun  Home      W  6.0
# 158  2023-04-05  21:00  Copa del Rey   Semi-finals  Wed  Away      W  4.0
#
#       ga         opponent  ... hour target gf_rolling  ga_rolling sh_rolling
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#            date   time          comp         round  day venue result   gf
# 0    2021-08-17  20:30  DFL-Supercup  DFL-Supercup  Tue  Away      W  3.0  \
# 1    2021-09-18  15:30    Bundesliga   Matchweek 5  Sat  Home      W  7.0
# 2    2021-09-24  20:30    Bundesliga   Matchweek 6  Fri  Away      W  3.0
# 3    2021-09-29  21:00  Champions Lg   Group stage  Wed  Home      W  5.0
# 4    2021-10-03  17:30    Bundesliga   Matchweek 7  Sun  Home      L  1.0
# ..          ...    ...           ...           ...  ...   ...    ...  ...
# 484  2023-02-25  18:30       La Liga  Matchweek 23  Sat  Home      D  1.0
# 485  2023-03-02  21:00  Copa del Rey   Semi-finals  Thu  Home      L  0.0
# 486  2023-03-19  21:00       La Liga  Matchweek 26  Sun  Away      L  1.0
# 487  2023-04-02  16:15       La Liga  Matchweek 27  Sun  Home      W  6.0
# 488  2023-04-05  21:00  Copa del Rey   Semi-finals  Wed  Away      W  4.0
#
#       ga         opponent  ... hour target gf_rolling  ga_rolling sh_rolling
# ...

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 combined, error = make_predictions(matches_rolling, predictors + new_cols)
#       2 error
#
# Cell In[103], line 4, in make_predictions(data, predictors)
#       2 train = data[data["date"] < '2023-01-01']
#       3 test = data[data["date"] > '2023-01-01']
# ----> 4 rf.fit(train[predictors], train["target"])
#       5 preds = rf.predict(test[predictors])
#       6 combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
#
# NameError: name 'rf' is not defined

# %%
combined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 combined
#
# NameError: name 'combined' is not defined

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
#       2 combined
#
# NameError: name 'combined' is not defined

# %%
combined.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 combined.head(10)
#
# NameError: name 'combined' is not defined

# %%
#venue_code
#home_stats
#away_stats

# %%
match1_home = home_stats[(home_stats['team'] == 'Real Madrid') | (home_stats['team'] == 'Chelsea')]
match1_away = away_stats[(away_stats['opponent'] == 'Real Madrid') | (away_stats['opponent'] == 'Chelsea')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'team'
#
# ...

# %%
match1_away = match1_away[:-1]
dates= [pd.to_datetime('2023-04-11'), pd.to_datetime('2023-04-11')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 match1_away = match1_away[:-1]
#       2 dates= [pd.to_datetime('2023-04-11'), pd.to_datetime('2023-04-11')]
#
# NameError: name 'match1_away' is not defined

# %%
match1_home.insert(loc=0,column='date', value=dates)
match1_home['day_code'] = [5,5]
match1_home['neutral_loc'] = [1,1]
match1_home['penalties'] = [0,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 match1_home.insert(loc=0,column='date', value=dates)
#       2 match1_home['day_code'] = [5,5]
#       3 match1_home['neutral_loc'] = [1,1]
#
# NameError: name 'match1_home' is not defined

# %%
match1_home.index =[0,1]
match1_away.index =[0,1]
match1 = pd.concat([match1_home, match1_away],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 match1_home.index =[0,1]
#       2 match1_away.index =[0,1]
#       3 match1 = pd.concat([match1_home, match1_away],axis=1)
#
# NameError: name 'match1_home' is not defined

# %%
match1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 match1
#
# NameError: name 'match1' is not defined

# %%
match1[['team', 'opponent']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 match1[['team', 'opponent']]
#
# NameError: name 'match1' is not defined

# %%
match1_preds = rf.predict(match1[predictors])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 match1_preds = rf.predict(match1[predictors])
#
# NameError: name 'rf' is not defined

# %%
match1_preds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 match1_preds
#
# NameError: name 'match1_preds' is not defined
