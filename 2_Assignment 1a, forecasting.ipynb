# %%
import pandas as pd
matches = pd.read_csv("matches.csv", index_col=0)
matches.shape
# Out:
# (5729, 27)

# %%
selected_teams = ['Bayern Munich', 'Napoli', 'Benfica', 'Real Madrid', 'Manchester City', 'Chelsea', 'Internazionale', 'Milan'] 
sm = selected_matches = matches[matches["team"].isin(selected_teams)]
sm.head()
# Out:
#          date   time          comp         round  day venue result   gf   ga  \
# 0  2022-07-30  20:30  DFL-Supercup  DFL-Supercup  Sat  Away      W  5.0  3.0
# 1  2022-08-05  20:30    Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2  2022-08-14  17:30    Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3  2022-08-21  17:30    Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4  2022-08-27  18:30    Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 0      RB Leipzig  ...  Match Report    NaN  12.0   8.0   NaN  NaN  0.0   0.0
# 1  Eint Frankfurt  ...  Match Report    NaN  23.0  10.0  16.6  1.0  0.0   0.0
# 2       Wolfsburg  ...  Match Report    NaN  24.0   8.0  18.4  0.0  0.0   0.0
# 3          Bochum  ...  Match Report    NaN  21.0  11.0  18.3  1.0  1.0   1.0
# 4      M'Gladbach  ...  Match Report    NaN  33.0  20.0  17.4  1.0  0.0   0.0
#
#   season           team
# ...

# %%
sm['opponent'] = sm['opponent'].str.replace('eng Chelsea', 'Chelsea')
sm['opponent'] = sm['opponent'].str.replace('de Bayern Munich', 'Bayern Munich')
sm['opponent'] = sm['opponent'].str.replace('eng Manchester City', 'Manchester City')
sm['opponent'] = sm['opponent'].str.replace('pt Benfica', 'Benfica')
sm['opponent'] = sm['opponent'].str.replace('es Real Madrid', 'Real Madrid')
sm['opponent'] = sm['opponent'].str.replace('it Inter', 'Internazionale')
sm['opponent'] = sm['opponent'].str.replace('Inter', 'Internazionale')
sm['opponent'] = sm['opponent'].str.replace('it Milan', 'Milan')
# Out:
# C:\Users\jchmi\AppData\Local\Temp\ipykernel_17968\3379978747.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['opponent'] = sm['opponent'].str.replace('eng Chelsea', 'Chelsea')
# C:\Users\jchmi\AppData\Local\Temp\ipykernel_17968\3379978747.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sm['opponent'] = sm['opponent'].str.replace('de Bayern Munich', 'Bayern Munich')
# C:\Users\jchmi\AppData\Local\Temp\ipykernel_17968\3379978747.py:3: SettingWithCopyWarning:
# ...

# %%
# new_rows = pd.DataFrame({
#     'date':['2004-03-11','2004-03-25', '2004-03-11', '2004-03-25', '2014-09-17', '2004-03-25', '2014-09-17-', '2004-03-25'],
#     'time':['19:00', '19:00', '19:00', '19:00', '20:45', '19:45', '20:45', '19:45'],
#     'comp':['UEFA cup', 'UEFA cup', 'UEFA cup', 'UEFA cup', 'Champions Lg', 'Champions Lg', 'Champions Lg', 'Champions Lg'],
#     'round':['Fourth round', 'Fourth round', 'Fourth round', 'Fourth round', 'Group stage', 'Group stage','Group stage','Group stage'],
#     'day': ['Thu', 'Thu', 'Thu', 'Thu', 'Wed', 'Tue', 'Wed', 'Tue'],
#     'venue': ['Home', 'Away', 'Away', 'Home', 'Home', 'Away', 'Away', 'Home'],
#     'result': ['D', 'L', 'D', 'W', 'W', 'L', 'L', 'W'], 
#     'gf': ['0', '3', '0', '4', '1', '2', '0', '3'],
#     'ga': ['0', '4', '0', '3', '0', '3', '1', '2'],
#     'opponent': ['it Inter', 'it Inter', 'pt Benfica', 'pt Benfica', 'eng Manchaster City', 'eng Manchaster City', 'de Bayern Munich', 'de Bayern Munich'],
#     'xg': ['0', '0', '0', '0', '0', '0', '0', '0'],
#     'xga': ['0', '0', '0', '0', '0', '0', '0', '0'],
#     'poss': ['0', '0', '0', '0', '58', '51', '42', '49'],
#     'attendence': ['0', '0', '0', '0', '68000', '44510', '68000', '44510'],
#     'captain': ['Jan Wegereef', 'Alain Sars', 'Jan Wegereef', 'Alain Sars', '0', '0', '0', '0'],
#     'formation': ['3-4-1-2', '4-2-3-1', '4-2-3-1', '4-2-3-1', '4-2-3-1', '4-2-3-1', '4-4-1-1', '4-1-4-1'],
#     'referee': ['Alain Sars', 'Jan Wegereef', 'Alain Sars', 'Jan Wegereef', 'Alberto Undiano', 'Pavel Královec', 'Alberto Undiano', 'Pavel Královec'], 
#     'match report':['Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report', 'Match Report'], 
#     'sh': ['18', '12', '12', '20', '0', '0', '0', '0'], 
#     'sot': ['3', '4', '4', '5', '0', '0', '0', '0'], 
#     'dist': ['0', '0', '0', '0', '0', '0', '0', '0'], 
#     'fk': ['0', '0', '0', '0', '0', '0', '0', '0'],
#     'pk': ['0', '0', '0', '0', '0', '0', '0', '0'], 
#     'pkatt': ['0', '0', '0', '0', '0', '0', '0', '0'],
#     'season': ['2004', '2004', '2004', '2004', '2014', '2014', '2014', '2014'], 
#     'team': ['Benefica', 'Benefica', 'Internazionale', 'Internazionale', 'Bayern Munich', 'Bayern Munich', 'Manchaster City', 'Manchaster City']
#            })

# sm = pd.concat([sm, new_rows], ignore_index=True)
# new_rows

new_rows = pd.DataFrame({'date':['2023-04-18', '2023-04-18', '2023-04-19', '2023-04-19'],
                         'time':['21:00', '21:00', '21:00', '21:00'],
                         'comp':['Champions Lg', 'Champions Lg', 'Champions Lg', 'Champions Lg'],
                         'round':['Quarter-finals', 'Quarter-finals', 'Quarter-finals', 'Quarter-finals'],
                         'day':['Tue', 'Tue', 'Wed', 'Wed'],
                         'venue':['Home', 'Home', 'Home', 'Home'],
                         'opponent':['Milan', 'Real Madrit', 'Benfica', 'Manchaster City'],
                         'referee':['István Kovács', 'FranÃ§ois Letexier', 'István Kovács', 'FranÃ§ois Letexier'],
                         'match report':['Match Report', 'Match Report', 'Match Report', 'Match Report'],
                         'season':['2023', '2023', '2023', '2023'],
                         'team':['Napoli', 'Chelsea', 'Internazionale', 'Bayern Munich']
                        })
sm = pd.concat([sm, new_rows], ignore_index=True)
new_rows
# Out:
#          date   time          comp           round  day venue  \
# 0  2023-04-18  21:00  Champions Lg  Quarter-finals  Tue  Home
# 1  2023-04-18  21:00  Champions Lg  Quarter-finals  Tue  Home
# 2  2023-04-19  21:00  Champions Lg  Quarter-finals  Wed  Home
# 3  2023-04-19  21:00  Champions Lg  Quarter-finals  Wed  Home
#
#           opponent             referee  match report season            team
# 0            Milan       István Kovács  Match Report   2023          Napoli
# 1      Real Madrit  FranÃ§ois Letexier  Match Report   2023         Chelsea
# 2          Benfica       István Kovács  Match Report   2023  Internazionale
# 3  Manchaster City  FranÃ§ois Letexier  Match Report   2023   Bayern Munich

# %%
sm.shape
# Out:
# (1340, 27)

# %%
# LIST OF VARIABLES:
#---------------------------------------------------------------------------------------------------------------------------
# Data - date od match.
# Time - time of match.
# Comp - type of competition
# Round - round or phase of competition.
# Day - the day of the week on which the match took place.
# Venue - away (game played at an opponent's ground), home (game played on the home ground).
# Result - match result.
# GF - goals for.
# GA - goals against.
# Opponent - opposing team.
# Poss - possession of the ball.
# Attendance - number of people in the stadium.
# Captain - team captain.
# Formation - how players are positioned on the pitch.
# Referee - main referee of the match.
# Sh - shots total.
# SoT - shots on target.
# Dist - average shot distance.
# Fk - shots from free kicks.
# Pk - penalty kicks made.
# PKatt - penalty kicks attempted.

# %%
# sm[sm["team"] == "Manchester City"].sort_values("date")

# %%
sm["date"] = pd.to_datetime(sm["date"])
sm["gf"] = pd.to_numeric(sm["gf"],errors = 'coerce')
sm["ga"] = pd.to_numeric(sm["gf"],errors = 'coerce')
sm['xg'] = sm['xg'].astype('float64')
sm['xga'] = sm['xga'].astype('float64')
sm['poss'] = sm['poss'].astype('float64')
sm['attendance'] = sm['attendance'].astype('float64')
sm['sh'] = sm['sh'].astype('float64')
sm['sot'] = sm['sot'].astype('float64')
sm['dist'] = sm['dist'].astype('float64')
sm['fk'] = sm['fk'].astype('float64')
sm["pkatt"] = sm["pkatt"].astype('float64')
sm["season"] = sm["season"].astype('int64')

# %%
sm.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                   object
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
# converting from a string into categories --> and categories into numbers 
sm["venue_code"] = sm["venue"].astype("category").cat.codes

# new column = venue code:
# 0 --> Away
# 1 --> Home

# %%
# assigning a code to every opponent, new column = opp code
sm["opp_code"] = sm["opponent"].astype("category").cat.codes

# %%
# converting time column into integer type, new column = hour
sm["hour"] = sm["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
# converting day column into integer type, new column = date
sm["day_code"] = sm["date"].dt.dayofweek

# Monday - 0
# Thuesday - 1
# ...

# %%
# converting target column into integer type, new column = hour
sm["target"] = (sm["result"] == "W").astype("int")

# Lost [L] --> 0 
# Draw [D] --> 0
# Win [W] --> 1

# %%
# !pip install -U scikit-learn

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = sm[sm["date"] < '2022-10-01']
test = sm[sm["date"] > '2022-10-01']

# %%
train.shape
# Out:
# (1081, 32)

# %%
test.shape
# Out:
# (254, 32)

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(test["target"], preds)
acc
# Out:
# 0.6417322834645669

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))
combined.shape
test.to_csv("test.csv")

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0    1
# actual
# 0          31   68
# 1          23  132

# %%
from sklearn.metrics import precision_score
precision_score(test["target"], preds)
# Out:
# 0.66

# %%
grouped_matches = sm.groupby("team")
group = grouped_matches.get_group("Manchester City").sort_values("date")
group.head()
# Out:
#            date   time              comp                round  day    venue  \
# 1024 2019-08-04  15:00  Community Shield  FA Community Shield  Sun  Neutral
# 1025 2019-08-10  12:30    Premier League          Matchweek 1  Sat     Away
# 1026 2019-08-17  17:30    Premier League          Matchweek 2  Sat     Home
# 1027 2019-08-25  14:00    Premier League          Matchweek 3  Sun     Away
# 1028 2019-08-31  15:00    Premier League          Matchweek 4  Sat     Home
#
#      result   gf   ga     opponent  ...   fk   pk  pkatt  season  \
# 1024      D  NaN  NaN    Liverpool  ...  NaN  0.0    0.0    2020
# 1025      W  5.0  5.0     West Ham  ...  0.0  1.0    1.0    2020
# 1026      D  2.0  2.0    Tottenham  ...  0.0  0.0    0.0    2020
# 1027      W  3.0  3.0  Bournemouth  ...  0.0  0.0    0.0    2020
# 1028      W  4.0  4.0     Brighton  ...  1.0  0.0    0.0    2020
#
#                  team venue_code opp_code hour day_code  target
# ...

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(10, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#            date   time            comp               round  day venue result  \
# 1050 2019-12-18  19:45         EFL Cup      Quarter-finals  Wed  Away      W
# 777  2020-11-28  15:00  Premier League        Matchweek 10  Sat  Home      W
# 778  2020-12-01  20:00    Champions Lg         Group stage  Tue  Away      D
# 779  2020-12-05  15:00  Premier League        Matchweek 11  Sat  Home      W
# 780  2020-12-09  20:00    Champions Lg         Group stage  Wed  Home      W
# 781  2020-12-12  17:30  Premier League        Matchweek 12  Sat  Away      D
# 782  2020-12-15  20:00  Premier League        Matchweek 13  Tue  Home      D
# 783  2020-12-19  15:00  Premier League        Matchweek 14  Sat  Away      W
# 784  2020-12-22  20:00         EFL Cup      Quarter-finals  Tue  Away      W
# 808  2021-03-20  17:30          FA Cup      Quarter-finals  Sat  Away      W
# 415  2021-12-14  20:00  Premier League        Matchweek 17  Tue  Home      W
# ...

# %%
matches_rolling = sm.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling = matches_rolling.droplevel('team')
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
matches_rolling.to_csv("matches_rolling.csv")

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-10-01']
    test = data[data["date"] > '2022-10-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
test
# Out:
#            date   time          comp           round  day venue result   gf  \
# 12   2022-10-04  18:45  Champions Lg     Group stage  Tue  Home      W  5.0
# 13   2022-10-08  18:30    Bundesliga     Matchweek 9  Sat  Away      D  2.0
# 14   2022-10-12  21:00  Champions Lg     Group stage  Wed  Away      W  4.0
# 15   2022-10-16  19:30    Bundesliga    Matchweek 10  Sun  Home      W  5.0
# 16   2022-10-19  20:45     DFB-Pokal     Round of 32  Wed  Away      W  5.0
# ...         ...    ...           ...             ...  ...   ...    ...  ...
# 333  2023-04-12  21:00  Champions Lg  Quarter-finals  Wed  Away      L  0.0
# 1336 2023-04-18  21:00  Champions Lg  Quarter-finals  Tue  Home    NaN  NaN
# 1337 2023-04-18  21:00  Champions Lg  Quarter-finals  Tue  Home    NaN  NaN
# 1338 2023-04-19  21:00  Champions Lg  Quarter-finals  Wed  Home    NaN  NaN
# 1339 2023-04-19  21:00  Champions Lg  Quarter-finals  Wed  Home    NaN  NaN
#
# ...

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.7073170731707317
